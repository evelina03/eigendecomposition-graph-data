# %%
import sys
import os
import time
import psutil
import pandas as pd
from neo4j import GraphDatabase

# %%
# Database connection setup
uri = "bolt://localhost:7687"
user = "neo4j"
password = "eigen1234"
database_name="d2.madelon"
driver = GraphDatabase.driver(uri, auth=(user, password))

# %%
# Neo4j connection
def create_session(uri, user, password):
    driver = GraphDatabase.driver(uri, auth=(user, password))
    return driver

# Function to run a query and measure performance metrics
def run_query(driver, query, parameters):
    # Start time and resources
    process = psutil.Process(os.getpid())
    start_time = time.time()
    start_cpu_times = process.cpu_times()
    start_mem = process.memory_info().rss  # Resident Set Size

    with driver.session(database=database_name) as session:
        result = session.run(query, parameters)
        record = result.single()
        data = record.data() if record else None

    # End time and resources
    end_time = time.time()
    end_cpu_times = process.cpu_times()
    end_mem = process.memory_info().rss

    # Calculations
    duration = end_time - start_time
    cpu_used = (end_cpu_times.user + end_cpu_times.system) - (start_cpu_times.user + start_cpu_times.system)
    memory_used = (end_mem - start_mem) / (1024 ** 2)  # Convert to MB

    return data, duration, memory_used, cpu_used

# %%
# Predefined experiments configurations with all combinations for each sub-dataset
experiments = []

# Define graph types and Laplacian methods
graph_types = ["full", "eps", "knn", "mknn"]
laplacian_types = ["sym", "rw", "ad"]

# Define parameters for each graph type per sub-dataset
parameters = {
    "madelon_33": {"full": "9", "eps": "1.141", "knn": "20", "mknn": "24"},
    "madelon_66": {"full": "5", "eps": "1.143", "knn": "14", "mknn": "16"},
    "madelon_full": {"full": "11", "eps": "1.161", "knn": "28", "mknn": "29"}
}

# Define number of eigenvectors and silhouette usage (common for all experiments)
number_of_eigenvectors = 3
use_kmean_for_silhouette = False

# Generate experiment configurations for each sub-dataset
sub_datasets = ["madelon_33", "madelon_66", "madelon_full"]
for sub_dataset in sub_datasets:
    for graph_type in graph_types:
        for laplacian_type in laplacian_types:
            experiments.append({
                "node_label": sub_dataset,
                "is_feature_based": True,
                "graph_type": graph_type,
                "parameter": parameters[sub_dataset][graph_type],
                "laplacian_type": laplacian_type,
                "number_of_eigenvectors": number_of_eigenvectors,
                "use_kmean_for_silhouette": use_kmean_for_silhouette
            })

# Print or analyze the configurations to ensure correctness
# for experiment in experiments:
#     print(experiment)

# %%
# Main function to run experiments
def run_experiments(driver):
    results = []
    total_experiments = len(experiments)
    for idx, config in enumerate(experiments, 1):
        query = """
        WITH simkit.spectralClustering({
            node_label: $node_label,
            is_feature_based: $is_feature_based,
            distance_measure: "euclidean",
            graph_type: $graph_type,
            parameter: $parameter,
            remove_columns: "index,target",
            laplacian_type: $laplacian_type,
            number_of_eigenvectors: $number_of_eigenvectors,
            number_of_iterations: "100",
            distance_measure_kmean: "euclidean",
            target_column: "target",
            use_kmean_for_silhouette: $use_kmean_for_silhouette,
            seed: 42
        }) AS silhouette_score
        WITH silhouette_score, simkit.adjustedRandIndex({
            nodeSet: $node_label,
            trueLabels: "target"
        }) AS rand_index
        RETURN silhouette_score, rand_index
        """
        # Run the combined query and collect metrics
        data, duration, memory_used, cpu_used = run_query(driver, query, config)
        silhouette_score = data['silhouette_score'] if data else None
        rand_index = data['rand_index'] if data else None

        # Save results
        results.append({
            **config,
            "silhouette_score": silhouette_score,
            "rand_index": rand_index,
            "duration": duration,
            "memory_used": memory_used,
            "cpu_used": cpu_used
        })
        # Print progress after each experiment
        print(f"Completed experiment {idx}/{total_experiments} with config: {config}")

    driver.close()
    return results

# %%
# # Example scheduling and execution
# def job():
#     print("Running experiments...")
#     result_data = run_experiments(driver)
#     # Save to DataFrame and then to CSV
#     df = pd.DataFrame(result_data)
#     df.to_csv("iris_results.csv", index=False)
#     print("Experiments completed and saved.")

# schedule.every().day.at("01:00").do(job)

# # Loop to keep the scheduler running
# while True:
#     schedule.run_pending()
#     time.sleep(60)  # wait one minute

print("Running experiments...")
result_data = run_experiments(driver)
# Save to DataFrame and then to CSV
df = pd.DataFrame(result_data)
df.to_csv("madelon_results.csv", index=False)
print("Experiments completed and saved.")
# Out:
# Running experiments...
# Completed experiment 1/36 with config: {'node_label': 'iris_full', 'is_feature_based': True, 'graph_type': 'full', 'parameter': '11', 'laplacian_type': 'sym', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 2/36 with config: {'node_label': 'iris_full', 'is_feature_based': True, 'graph_type': 'full', 'parameter': '11', 'laplacian_type': 'rw', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 3/36 with config: {'node_label': 'iris_full', 'is_feature_based': True, 'graph_type': 'full', 'parameter': '11', 'laplacian_type': 'ad', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 4/36 with config: {'node_label': 'iris_full', 'is_feature_based': True, 'graph_type': 'eps', 'parameter': '1.161', 'laplacian_type': 'sym', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 5/36 with config: {'node_label': 'iris_full', 'is_feature_based': True, 'graph_type': 'eps', 'parameter': '1.161', 'laplacian_type': 'rw', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 6/36 with config: {'node_label': 'iris_full', 'is_feature_based': True, 'graph_type': 'eps', 'parameter': '1.161', 'laplacian_type': 'ad', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 7/36 with config: {'node_label': 'iris_full', 'is_feature_based': True, 'graph_type': 'knn', 'parameter': '28', 'laplacian_type': 'sym', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 8/36 with config: {'node_label': 'iris_full', 'is_feature_based': True, 'graph_type': 'knn', 'parameter': '28', 'laplacian_type': 'rw', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 9/36 with config: {'node_label': 'iris_full', 'is_feature_based': True, 'graph_type': 'knn', 'parameter': '28', 'laplacian_type': 'ad', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 10/36 with config: {'node_label': 'iris_full', 'is_feature_based': True, 'graph_type': 'mknn', 'parameter': '29', 'laplacian_type': 'sym', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 11/36 with config: {'node_label': 'iris_full', 'is_feature_based': True, 'graph_type': 'mknn', 'parameter': '29', 'laplacian_type': 'rw', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 12/36 with config: {'node_label': 'iris_full', 'is_feature_based': True, 'graph_type': 'mknn', 'parameter': '29', 'laplacian_type': 'ad', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 13/36 with config: {'node_label': 'iris_3rd', 'is_feature_based': True, 'graph_type': 'full', 'parameter': '9', 'laplacian_type': 'sym', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 14/36 with config: {'node_label': 'iris_3rd', 'is_feature_based': True, 'graph_type': 'full', 'parameter': '9', 'laplacian_type': 'rw', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 15/36 with config: {'node_label': 'iris_3rd', 'is_feature_based': True, 'graph_type': 'full', 'parameter': '9', 'laplacian_type': 'ad', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 16/36 with config: {'node_label': 'iris_3rd', 'is_feature_based': True, 'graph_type': 'eps', 'parameter': '1.141', 'laplacian_type': 'sym', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 17/36 with config: {'node_label': 'iris_3rd', 'is_feature_based': True, 'graph_type': 'eps', 'parameter': '1.141', 'laplacian_type': 'rw', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 18/36 with config: {'node_label': 'iris_3rd', 'is_feature_based': True, 'graph_type': 'eps', 'parameter': '1.141', 'laplacian_type': 'ad', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 19/36 with config: {'node_label': 'iris_3rd', 'is_feature_based': True, 'graph_type': 'knn', 'parameter': '20', 'laplacian_type': 'sym', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 20/36 with config: {'node_label': 'iris_3rd', 'is_feature_based': True, 'graph_type': 'knn', 'parameter': '20', 'laplacian_type': 'rw', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 21/36 with config: {'node_label': 'iris_3rd', 'is_feature_based': True, 'graph_type': 'knn', 'parameter': '20', 'laplacian_type': 'ad', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 22/36 with config: {'node_label': 'iris_3rd', 'is_feature_based': True, 'graph_type': 'mknn', 'parameter': '24', 'laplacian_type': 'sym', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 23/36 with config: {'node_label': 'iris_3rd', 'is_feature_based': True, 'graph_type': 'mknn', 'parameter': '24', 'laplacian_type': 'rw', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 24/36 with config: {'node_label': 'iris_3rd', 'is_feature_based': True, 'graph_type': 'mknn', 'parameter': '24', 'laplacian_type': 'ad', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 25/36 with config: {'node_label': 'iris_6th', 'is_feature_based': True, 'graph_type': 'full', 'parameter': '5', 'laplacian_type': 'sym', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 26/36 with config: {'node_label': 'iris_6th', 'is_feature_based': True, 'graph_type': 'full', 'parameter': '5', 'laplacian_type': 'rw', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 27/36 with config: {'node_label': 'iris_6th', 'is_feature_based': True, 'graph_type': 'full', 'parameter': '5', 'laplacian_type': 'ad', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 28/36 with config: {'node_label': 'iris_6th', 'is_feature_based': True, 'graph_type': 'eps', 'parameter': '1.143', 'laplacian_type': 'sym', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 29/36 with config: {'node_label': 'iris_6th', 'is_feature_based': True, 'graph_type': 'eps', 'parameter': '1.143', 'laplacian_type': 'rw', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 30/36 with config: {'node_label': 'iris_6th', 'is_feature_based': True, 'graph_type': 'eps', 'parameter': '1.143', 'laplacian_type': 'ad', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 31/36 with config: {'node_label': 'iris_6th', 'is_feature_based': True, 'graph_type': 'knn', 'parameter': '14', 'laplacian_type': 'sym', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 32/36 with config: {'node_label': 'iris_6th', 'is_feature_based': True, 'graph_type': 'knn', 'parameter': '14', 'laplacian_type': 'rw', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 33/36 with config: {'node_label': 'iris_6th', 'is_feature_based': True, 'graph_type': 'knn', 'parameter': '14', 'laplacian_type': 'ad', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 34/36 with config: {'node_label': 'iris_6th', 'is_feature_based': True, 'graph_type': 'mknn', 'parameter': '16', 'laplacian_type': 'sym', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 35/36 with config: {'node_label': 'iris_6th', 'is_feature_based': True, 'graph_type': 'mknn', 'parameter': '16', 'laplacian_type': 'rw', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 36/36 with config: {'node_label': 'iris_6th', 'is_feature_based': True, 'graph_type': 'mknn', 'parameter': '16', 'laplacian_type': 'ad', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Experiments completed and saved.

# %%
result_data
# Out:
# [{'node_label': 'iris_full',
#   'is_feature_based': True,
#   'graph_type': 'full',
#   'parameter': '11',
#   'laplacian_type': 'sym',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.5055000468668748,
#   'rand_index': 0.7880443567941549,
#   'duration': 99.7205159664154,
#   'memory_used': -96.421875,
#   'cpu_used': 0.02040614399999985},
#  {'node_label': 'iris_full',
#   'is_feature_based': True,
#   'graph_type': 'full',
#   'parameter': '11',
#   'laplacian_type': 'rw',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.5066439011368349,
#   'rand_index': 0.7733799163281198,
#   'duration': 131.64908695220947,
#   'memory_used': 2.4375,
#   'cpu_used': 0.021565567999999757},
#  {'node_label': 'iris_full',
#   'is_feature_based': True,
#   'graph_type': 'full',
#   'parameter': '11',
#   'laplacian_type': 'ad',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.46741633379813646,
#   'rand_index': 0.902984110931228,
#   'duration': 124.26976013183594,
#   'memory_used': -4.609375,
#   'cpu_used': 0.01942054399999993},
#  {'node_label': 'iris_full',
#   'is_feature_based': True,
#   'graph_type': 'eps',
#   'parameter': '1.161',
#   'laplacian_type': 'sym',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.24610813069114512,
#   'rand_index': 0.0857719629832714,
#   'duration': 114.5362617969513,
#   'memory_used': -1.3125,
#   'cpu_used': 0.016642048000000464},
#  {'node_label': 'iris_full',
#   'is_feature_based': True,
#   'graph_type': 'eps',
#   'parameter': '1.161',
#   'laplacian_type': 'rw',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.24610813069114512,
#   'rand_index': 0.0857719629832714,
#   'duration': 117.9033043384552,
#   'memory_used': 0.078125,
#   'cpu_used': 0.016045312000000145},
#  {'node_label': 'iris_full',
#   'is_feature_based': True,
#   'graph_type': 'eps',
#   'parameter': '1.161',
#   'laplacian_type': 'ad',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.24610813069114512,
#   'rand_index': 0.0857719629832714,
#   'duration': 114.82495093345642,
#   'memory_used': -2.375,
#   'cpu_used': 0.017671808000000233},
#  {'node_label': 'iris_full',
#   'is_feature_based': True,
#   'graph_type': 'knn',
#   'parameter': '28',
#   'laplacian_type': 'sym',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.4825615156230673,
#   'rand_index': 0.97993200471804,
#   'duration': 27.075402975082397,
#   'memory_used': 1.328125,
#   'cpu_used': 0.009441536000000195},
#  {'node_label': 'iris_full',
#   'is_feature_based': True,
#   'graph_type': 'knn',
#   'parameter': '28',
#   'laplacian_type': 'rw',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.48256151562306693,
#   'rand_index': 0.97993200471804,
#   'duration': 26.35999822616577,
#   'memory_used': -0.0625,
#   'cpu_used': 0.007856384000000105},
#  {'node_label': 'iris_full',
#   'is_feature_based': True,
#   'graph_type': 'knn',
#   'parameter': '28',
#   'laplacian_type': 'ad',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.4795415470996706,
#   'rand_index': 0.9410449800736683,
#   'duration': 19.785783052444458,
#   'memory_used': 0.046875,
#   'cpu_used': 0.006569471999999799},
#  {'node_label': 'iris_full',
#   'is_feature_based': True,
#   'graph_type': 'mknn',
#   'parameter': '29',
#   'laplacian_type': 'sym',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.5016677928719064,
#   'rand_index': 0.7880443567941549,
#   'duration': 17.559768199920654,
#   'memory_used': 0.03125,
#   'cpu_used': 0.006171008000000366},
#  {'node_label': 'iris_full',
#   'is_feature_based': True,
#   'graph_type': 'mknn',
#   'parameter': '29',
#   'laplacian_type': 'rw',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.5068956113209233,
#   'rand_index': 0.7591987071071522,
#   'duration': 21.70971703529358,
#   'memory_used': 0.046875,
#   'cpu_used': 0.006867584000000093},
#  {'node_label': 'iris_full',
#   'is_feature_based': True,
#   'graph_type': 'mknn',
#   'parameter': '29',
#   'laplacian_type': 'ad',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.4666323413657618,
#   'rand_index': 0.902984110931228,
#   'duration': 18.25127100944519,
#   'memory_used': 0.046875,
#   'cpu_used': 0.006728320000000121},
#  {'node_label': 'iris_3rd',
#   'is_feature_based': True,
#   'graph_type': 'full',
#   'parameter': '9',
#   'laplacian_type': 'sym',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.4845828251971418,
#   'rand_index': 0.8801138918027873,
#   'duration': 11.626926898956299,
#   'memory_used': 0.375,
#   'cpu_used': 0.006385536000000247},
#  {'node_label': 'iris_3rd',
#   'is_feature_based': True,
#   'graph_type': 'full',
#   'parameter': '9',
#   'laplacian_type': 'rw',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.48927560207927245,
#   'rand_index': 0.9399759903961584,
#   'duration': 12.198868989944458,
#   'memory_used': -0.125,
#   'cpu_used': 0.006275456000000013},
#  {'node_label': 'iris_3rd',
#   'is_feature_based': True,
#   'graph_type': 'full',
#   'parameter': '9',
#   'laplacian_type': 'ad',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.4892848069796095,
#   'rand_index': 0.8243909729487371,
#   'duration': 14.891269207000732,
#   'memory_used': 0.015625,
#   'cpu_used': 0.005725695999999836},
#  {'node_label': 'iris_3rd',
#   'is_feature_based': True,
#   'graph_type': 'eps',
#   'parameter': '1.141',
#   'laplacian_type': 'sym',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.2811450498904265,
#   'rand_index': 0.1683599419448476,
#   'duration': 12.919103145599365,
#   'memory_used': 0.0,
#   'cpu_used': 0.006234112000000014},
#  {'node_label': 'iris_3rd',
#   'is_feature_based': True,
#   'graph_type': 'eps',
#   'parameter': '1.141',
#   'laplacian_type': 'rw',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.28114504989042644,
#   'rand_index': 0.1683599419448476,
#   'duration': 12.945438146591187,
#   'memory_used': 0.0,
#   'cpu_used': 0.006941824000000096},
#  {'node_label': 'iris_3rd',
#   'is_feature_based': True,
#   'graph_type': 'eps',
#   'parameter': '1.141',
#   'laplacian_type': 'ad',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.2811450498904265,
#   'rand_index': 0.19738751814223512,
#   'duration': 12.390305995941162,
#   'memory_used': 0.015625,
#   'cpu_used': 0.0065976320000000754},
#  {'node_label': 'iris_3rd',
#   'is_feature_based': True,
#   'graph_type': 'knn',
#   'parameter': '20',
#   'laplacian_type': 'sym',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.484473583165178,
#   'rand_index': 0.724251006111194,
#   'duration': 7.190363168716431,
#   'memory_used': 0.03125,
#   'cpu_used': 0.005766399999999727},
#  {'node_label': 'iris_3rd',
#   'is_feature_based': True,
#   'graph_type': 'knn',
#   'parameter': '20',
#   'laplacian_type': 'rw',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.488988295047904,
#   'rand_index': 0.7236851865588606,
#   'duration': 7.2740159034729,
#   'memory_used': 0.015625,
#   'cpu_used': 0.005114240000000159},
#  {'node_label': 'iris_3rd',
#   'is_feature_based': True,
#   'graph_type': 'knn',
#   'parameter': '20',
#   'laplacian_type': 'ad',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.48447358316517813,
#   'rand_index': 0.6758086152928902,
#   'duration': 7.322434186935425,
#   'memory_used': 0.015625,
#   'cpu_used': 0.006551808000000214},
#  {'node_label': 'iris_3rd',
#   'is_feature_based': True,
#   'graph_type': 'mknn',
#   'parameter': '24',
#   'laplacian_type': 'sym',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.48655569541842086,
#   'rand_index': 0.9399759903961584,
#   'duration': 6.66538405418396,
#   'memory_used': 0.015625,
#   'cpu_used': 0.005213567999999835},
#  {'node_label': 'iris_3rd',
#   'is_feature_based': True,
#   'graph_type': 'mknn',
#   'parameter': '24',
#   'laplacian_type': 'rw',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.4866153704196907,
#   'rand_index': 0.879951980792317,
#   'duration': 6.783576250076294,
#   'memory_used': 0.0,
#   'cpu_used': 0.0058406399999997305},
#  {'node_label': 'iris_3rd',
#   'is_feature_based': True,
#   'graph_type': 'mknn',
#   'parameter': '24',
#   'laplacian_type': 'ad',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.484582825197142,
#   'rand_index': 0.8838603326839503,
#   'duration': 6.485650062561035,
#   'memory_used': 0.046875,
#   'cpu_used': 0.006278015999999997},
#  {'node_label': 'iris_6th',
#   'is_feature_based': True,
#   'graph_type': 'full',
#   'parameter': '5',
#   'laplacian_type': 'sym',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.470892377886447,
#   'rand_index': 0.75573434066433,
#   'duration': 54.412840843200684,
#   'memory_used': -5.15625,
#   'cpu_used': 0.013123839999999998},
#  {'node_label': 'iris_6th',
#   'is_feature_based': True,
#   'graph_type': 'full',
#   'parameter': '5',
#   'laplacian_type': 'rw',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.4890593483867099,
#   'rand_index': 0.8817446785105328,
#   'duration': 56.70710825920105,
#   'memory_used': 4.25,
#   'cpu_used': 0.014576896000000339},
#  {'node_label': 'iris_6th',
#   'is_feature_based': True,
#   'graph_type': 'full',
#   'parameter': '5',
#   'laplacian_type': 'ad',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.4392556076271311,
#   'rand_index': 0.77822716136876,
#   'duration': 44.9743869304657,
#   'memory_used': -0.15625,
#   'cpu_used': 0.009292288000000148},
#  {'node_label': 'iris_6th',
#   'is_feature_based': True,
#   'graph_type': 'eps',
#   'parameter': '1.143',
#   'laplacian_type': 'sym',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.07929504529031305,
#   'rand_index': 0.2772529460912712,
#   'duration': 40.11472201347351,
#   'memory_used': 0.046875,
#   'cpu_used': 0.009531391999999528},
#  {'node_label': 'iris_6th',
#   'is_feature_based': True,
#   'graph_type': 'eps',
#   'parameter': '1.143',
#   'laplacian_type': 'rw',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.07929504529031305,
#   'rand_index': 0.2772529460912712,
#   'duration': 38.2983717918396,
#   'memory_used': 0.03125,
#   'cpu_used': 0.008792960000000072},
#  {'node_label': 'iris_6th',
#   'is_feature_based': True,
#   'graph_type': 'eps',
#   'parameter': '1.143',
#   'laplacian_type': 'ad',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.08522429139286186,
#   'rand_index': 0.25264513239657393,
#   'duration': 34.970861196517944,
#   'memory_used': 0.03125,
#   'cpu_used': 0.008633856000000328},
#  {'node_label': 'iris_6th',
#   'is_feature_based': True,
#   'graph_type': 'knn',
#   'parameter': '14',
#   'laplacian_type': 'sym',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.48436864255116946,
#   'rand_index': 0.8281504232252875,
#   'duration': 8.87029218673706,
#   'memory_used': 0.03125,
#   'cpu_used': 0.0063388160000004135},
#  {'node_label': 'iris_6th',
#   'is_feature_based': True,
#   'graph_type': 'knn',
#   'parameter': '14',
#   'laplacian_type': 'rw',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.48995303490499553,
#   'rand_index': 0.6852362096965494,
#   'duration': 9.565824031829834,
#   'memory_used': 0.046875,
#   'cpu_used': 0.006003968000000359},
#  {'node_label': 'iris_6th',
#   'is_feature_based': True,
#   'graph_type': 'knn',
#   'parameter': '14',
#   'laplacian_type': 'ad',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.4587376431219562,
#   'rand_index': 0.8293296140647078,
#   'duration': 7.980961084365845,
#   'memory_used': 0.0,
#   'cpu_used': 0.006008704000000087},
#  {'node_label': 'iris_6th',
#   'is_feature_based': True,
#   'graph_type': 'mknn',
#   'parameter': '16',
#   'laplacian_type': 'sym',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.4857395540523787,
#   'rand_index': 0.940300152464226,
#   'duration': 6.82433819770813,
#   'memory_used': 0.0,
#   'cpu_used': 0.005198592000000168},
#  {'node_label': 'iris_6th',
#   'is_feature_based': True,
#   'graph_type': 'mknn',
#   'parameter': '16',
#   'laplacian_type': 'rw',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.5005957002955111,
#   'rand_index': 0.6040898607050106,
#   'duration': 9.021652221679688,
#   'memory_used': 0.0,
#   'cpu_used': 0.006741504000000287},
#  {'node_label': 'iris_6th',
#   'is_feature_based': True,
#   'graph_type': 'mknn',
#   'parameter': '16',
#   'laplacian_type': 'ad',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.43001977744237413,
#   'rand_index': 0.6981782580230524,
#   'duration': 7.999377965927124,
#   'memory_used': 0.0,
#   'cpu_used': 0.006013183999999505}]
