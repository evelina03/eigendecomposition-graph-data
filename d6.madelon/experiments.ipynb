# %%
import sys
import os
import time
import psutil
import pandas as pd
from neo4j import GraphDatabase

# %%
# Database connection setup
uri = "bolt://localhost:7687"
user = "neo4j"
password = "eigen1234"
database_name="d2.madelon"
driver = GraphDatabase.driver(uri, auth=(user, password))

# %%
def check_connection():
    try:
        # Establish a session with the specified database
        # with driver.session(database=database_name) as session:
        with driver.session() as session:
            # Run a simple query to check the connection
            result = session.run("RETURN 'Connection to database successful' AS message")
            for record in result:
                print(record["message"])
    except Exception as e:
        print("Error connecting to the database:", e)

# Call the check_connection function
check_connection()
# Out:
# Connection to database successful

# %%
# Function to run a query and measure performance metrics
def run_query(driver, query, parameters):
    # Start time and resources
    process = psutil.Process(os.getpid())
    start_time = time.time()
    start_cpu_times = process.cpu_times()
    start_mem = process.memory_info().rss  # Resident Set Size

    # with driver.session(database=database_name) as session:
    with driver.session() as session:
        result = session.run(query, parameters)
        record = result.single()
        data = record.data() if record else None

    # End time and resources
    end_time = time.time()
    end_cpu_times = process.cpu_times()
    end_mem = process.memory_info().rss

    # Calculations
    duration = end_time - start_time
    cpu_used = (end_cpu_times.user + end_cpu_times.system) - (start_cpu_times.user + start_cpu_times.system)
    memory_used = (end_mem - start_mem) / (1024 ** 2)  # Convert to MB

    return data, duration, memory_used, cpu_used

# %%
# Predefined experiments configurations with all combinations for each sub-dataset
experiments = []

# Define graph types and Laplacian methods
graph_types = ["full", "eps", "knn", "mknn"]
laplacian_types = ["sym", "rw", "ad"]

# Define parameters for each graph type per sub-dataset
parameters = {
    "madelon_33": {"full": "26", "eps": "4.667", "knn": "138", "mknn": "55"}
}

# Define number of eigenvectors and silhouette usage (common for all experiments)
number_of_eigenvectors = 2
use_kmean_for_silhouette = False

# Generate experiment configurations for each sub-dataset
sub_datasets = ["madelon_33"]
for sub_dataset in sub_datasets:
    for graph_type in graph_types:
        for laplacian_type in laplacian_types:
            experiments.append({
                "node_label": sub_dataset,
                "is_feature_based": True,
                "graph_type": graph_type,
                "parameter": parameters[sub_dataset][graph_type],
                "laplacian_type": laplacian_type,
                "number_of_eigenvectors": number_of_eigenvectors,
                "use_kmean_for_silhouette": use_kmean_for_silhouette
            })

# Print or analyze the configurations to ensure correctness
# for experiment in experiments:
#     print(experiment)

# %%
def run_experiments(driver):
    results = []
    total_experiments = len(experiments)

    for idx, config in enumerate(experiments, 1):
        query = """
        WITH simkit.experimental_spectralClustering({
            node_label: $node_label,
            is_feature_based: $is_feature_based,
            distance_measure: "euclidean",
            graph_type: $graph_type,
            parameter: $parameter,
            remove_columns: "Index,target",
            laplacian_type: $laplacian_type,
            number_of_eigenvectors: $number_of_eigenvectors,
            number_of_iterations: "100",
            distance_measure_kmean: "euclidean",
            target_column: "target",
            use_kmean_for_silhouette: $use_kmean_for_silhouette,
            seed: 42
        }) AS result
        RETURN result.silhouette_score AS silhouette_score, 
               result.rand_index AS rand_index,
               result.total_time AS total_time,
               result.affinity_time AS affinity_time,
               result.laplacian_time AS laplacian_time,
               result.clustering_time AS clustering_time,
               result.adjusted_rand_index_time AS adjusted_rand_index_time
        """

        # Measure Memory and CPU Usage Before Query Execution
        memory_before = psutil.virtual_memory().used
        cpu_before = psutil.cpu_percent(interval=None)

        # Execute the Query and Measure Time
        start_time = time.perf_counter()
        data, _, _, _ = run_query(driver, query, config)
        elapsed_time = time.perf_counter() - start_time

        # Measure Memory and CPU Usage After Query Execution
        memory_after = psutil.virtual_memory().used
        cpu_after = psutil.cpu_percent(interval=None)

        # Calculate Metrics
        memory_used = (memory_after - memory_before) / 1e6  # Memory in MB
        cpu_used = (cpu_before + cpu_after) / 2  # Average CPU usage

        # Extract Results from Java
        silhouette_score = data['silhouette_score'] if data else None
        rand_index = data['rand_index'] if data else None
        total_time = data['total_time'] if data else None
        affinity_time = data['affinity_time'] if data else None
        laplacian_time = data['laplacian_time'] if data else None
        clustering_time = data['clustering_time'] if data else None
        adjusted_rand_index_time = data['adjusted_rand_index_time'] if data else None

        # Save Results
        results.append({
            **config,
            "silhouette_score": silhouette_score,
            "rand_index": rand_index,
            "total_time": total_time or elapsed_time,
            "affinity_time": affinity_time,
            "laplacian_time": laplacian_time,
            "clustering_time": clustering_time,
            "adjusted_rand_index_time": adjusted_rand_index_time,
            "memory_used": memory_used,
            "cpu_used": cpu_used
        })

        print(f"Completed experiment {idx}/{total_experiments} with config: {config}")

    driver.close()
    return results

# %%
# # Example scheduling and execution
# def job():
#     print("Running experiments...")
#     result_data = run_experiments(driver)
#     # Save to DataFrame and then to CSV
#     df = pd.DataFrame(result_data)
#     df.to_csv("iris_results.csv", index=False)
#     print("Experiments completed and saved.")

# schedule.every().day.at("01:00").do(job)

# # Loop to keep the scheduler running
# while True:
#     schedule.run_pending()
#     time.sleep(60)  # wait one minute

print("Running experiments...")
result_data1 = run_experiments(driver)
# Save to DataFrame and then to CSV
df1 = pd.DataFrame(result_data1)
df1.to_csv("madelon_results1.csv", index=False)
print("Experiments completed and saved.")
# Out:
# Running experiments...
# Completed experiment 1/12 with config: {'node_label': 'madelon_33', 'is_feature_based': True, 'graph_type': 'full', 'parameter': '26', 'laplacian_type': 'sym', 'number_of_eigenvectors': 2, 'use_kmean_for_silhouette': False}
# Completed experiment 2/12 with config: {'node_label': 'madelon_33', 'is_feature_based': True, 'graph_type': 'full', 'parameter': '26', 'laplacian_type': 'rw', 'number_of_eigenvectors': 2, 'use_kmean_for_silhouette': False}
# Completed experiment 3/12 with config: {'node_label': 'madelon_33', 'is_feature_based': True, 'graph_type': 'full', 'parameter': '26', 'laplacian_type': 'ad', 'number_of_eigenvectors': 2, 'use_kmean_for_silhouette': False}
# Completed experiment 4/12 with config: {'node_label': 'madelon_33', 'is_feature_based': True, 'graph_type': 'eps', 'parameter': '4.667', 'laplacian_type': 'sym', 'number_of_eigenvectors': 2, 'use_kmean_for_silhouette': False}
# Completed experiment 5/12 with config: {'node_label': 'madelon_33', 'is_feature_based': True, 'graph_type': 'eps', 'parameter': '4.667', 'laplacian_type': 'rw', 'number_of_eigenvectors': 2, 'use_kmean_for_silhouette': False}
# Completed experiment 6/12 with config: {'node_label': 'madelon_33', 'is_feature_based': True, 'graph_type': 'eps', 'parameter': '4.667', 'laplacian_type': 'ad', 'number_of_eigenvectors': 2, 'use_kmean_for_silhouette': False}
# Completed experiment 7/12 with config: {'node_label': 'madelon_33', 'is_feature_based': True, 'graph_type': 'knn', 'parameter': '138', 'laplacian_type': 'sym', 'number_of_eigenvectors': 2, 'use_kmean_for_silhouette': False}
# Completed experiment 8/12 with config: {'node_label': 'madelon_33', 'is_feature_based': True, 'graph_type': 'knn', 'parameter': '138', 'laplacian_type': 'rw', 'number_of_eigenvectors': 2, 'use_kmean_for_silhouette': False}
# Completed experiment 9/12 with config: {'node_label': 'madelon_33', 'is_feature_based': True, 'graph_type': 'knn', 'parameter': '138', 'laplacian_type': 'ad', 'number_of_eigenvectors': 2, 'use_kmean_for_silhouette': False}
# Completed experiment 10/12 with config: {'node_label': 'madelon_33', 'is_feature_based': True, 'graph_type': 'mknn', 'parameter': '55', 'laplacian_type': 'sym', 'number_of_eigenvectors': 2, 'use_kmean_for_silhouette': False}
# Completed experiment 11/12 with config: {'node_label': 'madelon_33', 'is_feature_based': True, 'graph_type': 'mknn', 'parameter': '55', 'laplacian_type': 'rw', 'number_of_eigenvectors': 2, 'use_kmean_for_silhouette': False}
# Completed experiment 12/12 with config: {'node_label': 'madelon_33', 'is_feature_based': True, 'graph_type': 'mknn', 'parameter': '55', 'laplacian_type': 'ad', 'number_of_eigenvectors': 2, 'use_kmean_for_silhouette': False}
# Experiments completed and saved.

# %%
result_data1
# Out:
# [{'node_label': 'madelon_33',
#   'is_feature_based': True,
#   'graph_type': 'full',
#   'parameter': '26',
#   'laplacian_type': 'sym',
#   'number_of_eigenvectors': 2,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.010866799180726533,
#   'rand_index': 0.7884990231139244,
#   'total_time': 1401431.415459,
#   'affinity_time': 25758.569375,
#   'laplacian_time': 1142844.359709,
#   'clustering_time': 232472.184042,
#   'adjusted_rand_index_time': 354.548459,
#   'memory_used': -600.80128,
#   'cpu_used': 33.0},
#  {'node_label': 'madelon_33',
#   'is_feature_based': True,
#   'graph_type': 'full',
#   'parameter': '26',
#   'laplacian_type': 'rw',
#   'number_of_eigenvectors': 2,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.011074421861220774,
#   'rand_index': 0.7435624212240732,
#   'total_time': 1481497.774,
#   'affinity_time': 22882.101709,
#   'laplacian_time': 1225331.831209,
#   'clustering_time': 232948.432083,
#   'adjusted_rand_index_time': 334.941958,
#   'memory_used': -274.644992,
#   'cpu_used': 20.45},
#  {'node_label': 'madelon_33',
#   'is_feature_based': True,
#   'graph_type': 'full',
#   'parameter': '26',
#   'laplacian_type': 'ad',
#   'number_of_eigenvectors': 2,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.010859121210458761,
#   'rand_index': 0.8009831033257659,
#   'total_time': 991159.614542,
#   'affinity_time': 22998.763292,
#   'laplacian_time': 846972.048084,
#   'clustering_time': 120896.963084,
#   'adjusted_rand_index_time': 291.383167,
#   'memory_used': -267.14112,
#   'cpu_used': 26.1},
#  {'node_label': 'madelon_33',
#   'is_feature_based': True,
#   'graph_type': 'eps',
#   'parameter': '4.667',
#   'laplacian_type': 'sym',
#   'number_of_eigenvectors': 2,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.012399302779413784,
#   'rand_index': 0.3228499321912496,
#   'total_time': 982706.201416,
#   'affinity_time': 13486.389333,
#   'laplacian_time': 852547.597375,
#   'clustering_time': 116377.175208,
#   'adjusted_rand_index_time': 294.721542,
#   'memory_used': -143.507456,
#   'cpu_used': 26.0},
#  {'node_label': 'madelon_33',
#   'is_feature_based': True,
#   'graph_type': 'eps',
#   'parameter': '4.667',
#   'laplacian_type': 'rw',
#   'number_of_eigenvectors': 2,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.011981073377465682,
#   'rand_index': 0.33624873371767694,
#   'total_time': 1061692.279916,
#   'affinity_time': 28835.183417,
#   'laplacian_time': 893248.136583,
#   'clustering_time': 139272.720875,
#   'adjusted_rand_index_time': 335.36325,
#   'memory_used': 110.575616,
#   'cpu_used': 23.25},
#  {'node_label': 'madelon_33',
#   'is_feature_based': True,
#   'graph_type': 'eps',
#   'parameter': '4.667',
#   'laplacian_type': 'ad',
#   'number_of_eigenvectors': 2,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.013257744480484446,
#   'rand_index': 0.2528518277483761,
#   'total_time': 847128.025833,
#   'affinity_time': 13722.133917,
#   'laplacian_time': 694160.037791,
#   'clustering_time': 138916.60225,
#   'adjusted_rand_index_time': 328.453334,
#   'memory_used': 53.428224,
#   'cpu_used': 59.05},
#  {'node_label': 'madelon_33',
#   'is_feature_based': True,
#   'graph_type': 'knn',
#   'parameter': '138',
#   'laplacian_type': 'sym',
#   'number_of_eigenvectors': 2,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.010987019970693974,
#   'rand_index': 0.642586480962637,
#   'total_time': 352981.049459,
#   'affinity_time': 8122.436542,
#   'laplacian_time': 198317.837416,
#   'clustering_time': 146217.916458,
#   'adjusted_rand_index_time': 322.115834,
#   'memory_used': -69.107712,
#   'cpu_used': 9.45},
#  {'node_label': 'madelon_33',
#   'is_feature_based': True,
#   'graph_type': 'knn',
#   'parameter': '138',
#   'laplacian_type': 'rw',
#   'number_of_eigenvectors': 2,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.008961935691323374,
#   'rand_index': 0.36105317275767146,
#   'total_time': 349450.670291,
#   'affinity_time': 8883.139167,
#   'laplacian_time': 196885.240834,
#   'clustering_time': 143353.095708,
#   'adjusted_rand_index_time': 328.386875,
#   'memory_used': -149.58592,
#   'cpu_used': 9.25},
#  {'node_label': 'madelon_33',
#   'is_feature_based': True,
#   'graph_type': 'knn',
#   'parameter': '138',
#   'laplacian_type': 'ad',
#   'number_of_eigenvectors': 2,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.010404656792390395,
#   'rand_index': 0.8009831033257659,
#   'total_time': 350275.810167,
#   'affinity_time': 8789.973333,
#   'laplacian_time': 202701.368333,
#   'clustering_time': 138456.621375,
#   'adjusted_rand_index_time': 327.167084,
#   'memory_used': -357.564416,
#   'cpu_used': 9.85},
#  {'node_label': 'madelon_33',
#   'is_feature_based': True,
#   'graph_type': 'mknn',
#   'parameter': '55',
#   'laplacian_type': 'sym',
#   'number_of_eigenvectors': 2,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.0034494195441830042,
#   'rand_index': 0.8177809609254371,
#   'total_time': 184336.313125,
#   'affinity_time': 7852.002542,
#   'laplacian_time': 36152.245959,
#   'clustering_time': 140008.19375,
#   'adjusted_rand_index_time': 323.071,
#   'memory_used': 233.242624,
#   'cpu_used': 10.4},
#  {'node_label': 'madelon_33',
#   'is_feature_based': True,
#   'graph_type': 'mknn',
#   'parameter': '55',
#   'laplacian_type': 'rw',
#   'number_of_eigenvectors': 2,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.023166777321055713,
#   'rand_index': 3.2640003359926235e-05,
#   'total_time': 188295.477916,
#   'affinity_time': 7842.871292,
#   'laplacian_time': 37184.244666,
#   'clustering_time': 142979.37575,
#   'adjusted_rand_index_time': 288.438334,
#   'memory_used': 215.269376,
#   'cpu_used': 10.3},
#  {'node_label': 'madelon_33',
#   'is_feature_based': True,
#   'graph_type': 'mknn',
#   'parameter': '55',
#   'laplacian_type': 'ad',
#   'number_of_eigenvectors': 2,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': -0.008109646307224303,
#   'rand_index': 0.4532473155274146,
#   'total_time': 196461.667291,
#   'affinity_time': 7976.691458,
#   'laplacian_time': 36501.312375,
#   'clustering_time': 151661.223083,
#   'adjusted_rand_index_time': 321.802042,
#   'memory_used': -86.491136,
#   'cpu_used': 8.9}]

# %%
# Predefined experiments configurations with all combinations for each sub-dataset
experiments = []

# Define graph types and Laplacian methods
graph_types = ["full", "eps", "knn", "mknn"]
laplacian_types = ["sym", "rw", "ad"]

# Define parameters for each graph type per sub-dataset
parameters = {
    "madelon_66": {"full": "33", "eps": "4.669", "knn": "271", "mknn": "77"}
}

# Define number of eigenvectors and silhouette usage (common for all experiments)
number_of_eigenvectors = 2
use_kmean_for_silhouette = False

# Generate experiment configurations for each sub-dataset
sub_datasets = ["madelon_66"]
for sub_dataset in sub_datasets:
    for graph_type in graph_types:
        for laplacian_type in laplacian_types:
            experiments.append({
                "node_label": sub_dataset,
                "is_feature_based": True,
                "graph_type": graph_type,
                "parameter": parameters[sub_dataset][graph_type],
                "laplacian_type": laplacian_type,
                "number_of_eigenvectors": number_of_eigenvectors,
                "use_kmean_for_silhouette": use_kmean_for_silhouette
            })

# Print or analyze the configurations to ensure correctness
# for experiment in experiments:
#     print(experiment)

# %%
def run_experiments(driver):
    results = []
    total_experiments = len(experiments)

    for idx, config in enumerate(experiments, 1):
        query = """
        WITH simkit.experimental_spectralClustering({
            node_label: $node_label,
            is_feature_based: $is_feature_based,
            distance_measure: "euclidean",
            graph_type: $graph_type,
            parameter: $parameter,
            remove_columns: "Index,target",
            laplacian_type: $laplacian_type,
            number_of_eigenvectors: $number_of_eigenvectors,
            number_of_iterations: "100",
            distance_measure_kmean: "euclidean",
            target_column: "target",
            use_kmean_for_silhouette: $use_kmean_for_silhouette,
            seed: 42
        }) AS result
        RETURN result.silhouette_score AS silhouette_score, 
               result.rand_index AS rand_index,
               result.total_time AS total_time,
               result.affinity_time AS affinity_time,
               result.laplacian_time AS laplacian_time,
               result.clustering_time AS clustering_time,
               result.adjusted_rand_index_time AS adjusted_rand_index_time
        """

        # Measure Memory and CPU Usage Before Query Execution
        memory_before = psutil.virtual_memory().used
        cpu_before = psutil.cpu_percent(interval=None)

        # Execute the Query and Measure Time
        start_time = time.perf_counter()
        data, _, _, _ = run_query(driver, query, config)
        elapsed_time = time.perf_counter() - start_time

        # Measure Memory and CPU Usage After Query Execution
        memory_after = psutil.virtual_memory().used
        cpu_after = psutil.cpu_percent(interval=None)

        # Calculate Metrics
        memory_used = (memory_after - memory_before) / 1e6  # Memory in MB
        cpu_used = (cpu_before + cpu_after) / 2  # Average CPU usage

        # Extract Results from Java
        silhouette_score = data['silhouette_score'] if data else None
        rand_index = data['rand_index'] if data else None
        total_time = data['total_time'] if data else None
        affinity_time = data['affinity_time'] if data else None
        laplacian_time = data['laplacian_time'] if data else None
        clustering_time = data['clustering_time'] if data else None
        adjusted_rand_index_time = data['adjusted_rand_index_time'] if data else None

        # Save Results
        results.append({
            **config,
            "silhouette_score": silhouette_score,
            "rand_index": rand_index,
            "total_time": total_time or elapsed_time,
            "affinity_time": affinity_time,
            "laplacian_time": laplacian_time,
            "clustering_time": clustering_time,
            "adjusted_rand_index_time": adjusted_rand_index_time,
            "memory_used": memory_used,
            "cpu_used": cpu_used
        })

        print(f"Completed experiment {idx}/{total_experiments} with config: {config}")

    driver.close()
    return results

# %%
# # Example scheduling and execution
# def job():
#     print("Running experiments...")
#     result_data = run_experiments(driver)
#     # Save to DataFrame and then to CSV
#     df = pd.DataFrame(result_data)
#     df.to_csv("iris_results.csv", index=False)
#     print("Experiments completed and saved.")

# schedule.every().day.at("01:00").do(job)

# # Loop to keep the scheduler running
# while True:
#     schedule.run_pending()
#     time.sleep(60)  # wait one minute

print("Running experiments...")
result_data2 = run_experiments(driver)
# Save to DataFrame and then to CSV
df2 = pd.DataFrame(result_data2)
df2.to_csv("madelon_results2.csv", index=False)
print("Experiments completed and saved.")
# Out:
# Running experiments...
# /var/folders/5m/3t1ykjr55_555tllby0d28j00000gn/T/ipykernel_92732/333463505.py:10: DeprecationWarning: Using a driver after it has been closed is deprecated. Future versions of the driver will raise an error.
#   with driver.session() as session:
# Completed experiment 1/12 with config: {'node_label': 'madelon_66', 'is_feature_based': True, 'graph_type': 'full', 'parameter': '33', 'laplacian_type': 'sym', 'number_of_eigenvectors': 2, 'use_kmean_for_silhouette': False}
# Completed experiment 2/12 with config: {'node_label': 'madelon_66', 'is_feature_based': True, 'graph_type': 'full', 'parameter': '33', 'laplacian_type': 'rw', 'number_of_eigenvectors': 2, 'use_kmean_for_silhouette': False}
# Completed experiment 3/12 with config: {'node_label': 'madelon_66', 'is_feature_based': True, 'graph_type': 'full', 'parameter': '33', 'laplacian_type': 'ad', 'number_of_eigenvectors': 2, 'use_kmean_for_silhouette': False}
# Completed experiment 4/12 with config: {'node_label': 'madelon_66', 'is_feature_based': True, 'graph_type': 'eps', 'parameter': '4.669', 'laplacian_type': 'sym', 'number_of_eigenvectors': 2, 'use_kmean_for_silhouette': False}
# Completed experiment 5/12 with config: {'node_label': 'madelon_66', 'is_feature_based': True, 'graph_type': 'eps', 'parameter': '4.669', 'laplacian_type': 'rw', 'number_of_eigenvectors': 2, 'use_kmean_for_silhouette': False}
# Completed experiment 6/12 with config: {'node_label': 'madelon_66', 'is_feature_based': True, 'graph_type': 'eps', 'parameter': '4.669', 'laplacian_type': 'ad', 'number_of_eigenvectors': 2, 'use_kmean_for_silhouette': False}
# Completed experiment 7/12 with config: {'node_label': 'madelon_66', 'is_feature_based': True, 'graph_type': 'knn', 'parameter': '271', 'laplacian_type': 'sym', 'number_of_eigenvectors': 2, 'use_kmean_for_silhouette': False}
# Completed experiment 8/12 with config: {'node_label': 'madelon_66', 'is_feature_based': True, 'graph_type': 'knn', 'parameter': '271', 'laplacian_type': 'rw', 'number_of_eigenvectors': 2, 'use_kmean_for_silhouette': False}
# Completed experiment 9/12 with config: {'node_label': 'madelon_66', 'is_feature_based': True, 'graph_type': 'knn', 'parameter': '271', 'laplacian_type': 'ad', 'number_of_eigenvectors': 2, 'use_kmean_for_silhouette': False}
# Completed experiment 10/12 with config: {'node_label': 'madelon_66', 'is_feature_based': True, 'graph_type': 'mknn', 'parameter': '77', 'laplacian_type': 'sym', 'number_of_eigenvectors': 2, 'use_kmean_for_silhouette': False}
# Completed experiment 11/12 with config: {'node_label': 'madelon_66', 'is_feature_based': True, 'graph_type': 'mknn', 'parameter': '77', 'laplacian_type': 'rw', 'number_of_eigenvectors': 2, 'use_kmean_for_silhouette': False}
# Completed experiment 12/12 with config: {'node_label': 'madelon_66', 'is_feature_based': True, 'graph_type': 'mknn', 'parameter': '77', 'laplacian_type': 'ad', 'number_of_eigenvectors': 2, 'use_kmean_for_silhouette': False}
# Experiments completed and saved.

# %%
result_data2
# Out:
# [{'node_label': 'madelon_66',
#   'is_feature_based': True,
#   'graph_type': 'full',
#   'parameter': '33',
#   'laplacian_type': 'sym',
#   'number_of_eigenvectors': 2,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.01097172906627428,
#   'rand_index': 0.9200323990515031,
#   'total_time': 11236400.154916,
#   'affinity_time': 48319.491958,
#   'laplacian_time': 10659360.593792,
#   'clustering_time': 528278.89975,
#   'adjusted_rand_index_time': 438.781875,
#   'memory_used': 165.888,
#   'cpu_used': 12.899999999999999},
#  {'node_label': 'madelon_66',
#   'is_feature_based': True,
#   'graph_type': 'full',
#   'parameter': '33',
#   'laplacian_type': 'rw',
#   'number_of_eigenvectors': 2,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.01103436279420762,
#   'rand_index': 0.8714716730086772,
#   'total_time': 13221426.579791,
#   'affinity_time': 56689.322958,
#   'laplacian_time': 12604134.02725,
#   'clustering_time': 560139.751417,
#   'adjusted_rand_index_time': 462.799042,
#   'memory_used': -247.136256,
#   'cpu_used': 8.4},
#  {'node_label': 'madelon_66',
#   'is_feature_based': True,
#   'graph_type': 'full',
#   'parameter': '33',
#   'laplacian_type': 'ad',
#   'number_of_eigenvectors': 2,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.010964869289774675,
#   'rand_index': 0.9267562714986911,
#   'total_time': 11250425.917625,
#   'affinity_time': 59388.082333,
#   'laplacian_time': 10651271.773417,
#   'clustering_time': 539369.5315,
#   'adjusted_rand_index_time': 396.049791,
#   'memory_used': 179.027968,
#   'cpu_used': 8.55},
#  {'node_label': 'madelon_66',
#   'is_feature_based': True,
#   'graph_type': 'eps',
#   'parameter': '4.669',
#   'laplacian_type': 'sym',
#   'number_of_eigenvectors': 2,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.013676435669104243,
#   'rand_index': 0.25318061435941114,
#   'total_time': 11267494.872542,
#   'affinity_time': 43806.607542,
#   'laplacian_time': 10670748.867333,
#   'clustering_time': 552518.090542,
#   'adjusted_rand_index_time': 420.678667,
#   'memory_used': -143.85152,
#   'cpu_used': 9.55},
#  {'node_label': 'madelon_66',
#   'is_feature_based': True,
#   'graph_type': 'eps',
#   'parameter': '4.669',
#   'laplacian_type': 'rw',
#   'number_of_eigenvectors': 2,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.01282612554104493,
#   'rand_index': 0.3218472098898398,
#   'total_time': 12261740.971083,
#   'affinity_time': 56767.254291,
#   'laplacian_time': 11244791.916792,
#   'clustering_time': 959739.782417,
#   'adjusted_rand_index_time': 441.315125,
#   'memory_used': 1823.834112,
#   'cpu_used': 8.7},
#  {'node_label': 'madelon_66',
#   'is_feature_based': True,
#   'graph_type': 'eps',
#   'parameter': '4.669',
#   'laplacian_type': 'ad',
#   'number_of_eigenvectors': 2,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.014389140605454362,
#   'rand_index': 0.20417311551347014,
#   'total_time': 19355757.888667,
#   'affinity_time': 93479.804625,
#   'laplacian_time': 18219238.417083,
#   'clustering_time': 1042566.340292,
#   'adjusted_rand_index_time': 472.721125,
#   'memory_used': -2950.168576,
#   'cpu_used': 8.1},
#  {'node_label': 'madelon_66',
#   'is_feature_based': True,
#   'graph_type': 'knn',
#   'parameter': '271',
#   'laplacian_type': 'sym',
#   'number_of_eigenvectors': 2,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.010890017072558811,
#   'rand_index': 0.7619232329164155,
#   'total_time': 4361245.652417,
#   'affinity_time': 54848.733291,
#   'laplacian_time': 3798540.269541,
#   'clustering_time': 507459.644541,
#   'adjusted_rand_index_time': 394.982334,
#   'memory_used': 1805.729792,
#   'cpu_used': 15.9},
#  {'node_label': 'madelon_66',
#   'is_feature_based': True,
#   'graph_type': 'knn',
#   'parameter': '271',
#   'laplacian_type': 'rw',
#   'number_of_eigenvectors': 2,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.009045279425879247,
#   'rand_index': 0.47901491980861777,
#   'total_time': 3608529.838708,
#   'affinity_time': 32713.722667,
#   'laplacian_time': 2991961.61075,
#   'clustering_time': 583326.588708,
#   'adjusted_rand_index_time': 527.219625,
#   'memory_used': -1347.141632,
#   'cpu_used': 58.9},
#  {'node_label': 'madelon_66',
#   'is_feature_based': True,
#   'graph_type': 'knn',
#   'parameter': '271',
#   'laplacian_type': 'ad',
#   'number_of_eigenvectors': 2,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.010425594250510822,
#   'rand_index': 0.9267562714986911,
#   'total_time': 3672395.5985,
#   'affinity_time': 33968.930792,
#   'laplacian_time': 3016354.744,
#   'clustering_time': 621608.3115,
#   'adjusted_rand_index_time': 463.084417,
#   'memory_used': 840.187904,
#   'cpu_used': 10.2},
#  {'node_label': 'madelon_66',
#   'is_feature_based': True,
#   'graph_type': 'mknn',
#   'parameter': '77',
#   'laplacian_type': 'sym',
#   'number_of_eigenvectors': 2,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.0009440307777265526,
#   'rand_index': 0.986054757221533,
#   'total_time': 946083.251834,
#   'affinity_time': 30723.209208,
#   'laplacian_time': 354866.540042,
#   'clustering_time': 560094.451375,
#   'adjusted_rand_index_time': 398.525167,
#   'memory_used': -730.23488,
#   'cpu_used': 10.55},
#  {'node_label': 'madelon_66',
#   'is_feature_based': True,
#   'graph_type': 'mknn',
#   'parameter': '77',
#   'laplacian_type': 'rw',
#   'number_of_eigenvectors': 2,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.03041978553821932,
#   'rand_index': 2.7183774461835777e-06,
#   'total_time': 1131441.206,
#   'affinity_time': 31493.102417,
#   'laplacian_time': 352817.291708,
#   'clustering_time': 746660.559916,
#   'adjusted_rand_index_time': 469.57075,
#   'memory_used': -318.01344,
#   'cpu_used': 11.25},
#  {'node_label': 'madelon_66',
#   'is_feature_based': True,
#   'graph_type': 'mknn',
#   'parameter': '77',
#   'laplacian_type': 'ad',
#   'number_of_eigenvectors': 2,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': -0.008839248976422354,
#   'rand_index': 0.42569755979579255,
#   'total_time': 1758329.168208,
#   'affinity_time': 52241.664875,
#   'laplacian_time': 610359.430166,
#   'clustering_time': 1094773.515917,
#   'adjusted_rand_index_time': 954.094667,
#   'memory_used': 53.886976,
#   'cpu_used': 35.55}]

# %%
# Predefined experiments configurations with all combinations for each sub-dataset
experiments = []

# Define graph types and Laplacian methods
graph_types = ["full", "eps", "knn", "mknn"]
laplacian_types = ["sym", "rw", "ad"]

# Define parameters for each graph type per sub-dataset
parameters = {
    "madelon_full": {"full": "45", "eps": "4.669", "knn": "419", "mknn": "117"}
}

# Define number of eigenvectors and silhouette usage (common for all experiments)
number_of_eigenvectors = 3
use_kmean_for_silhouette = False

# Generate experiment configurations for each sub-dataset
sub_datasets = ["madelon_full"]
for sub_dataset in sub_datasets:
    for graph_type in graph_types:
        for laplacian_type in laplacian_types:
            experiments.append({
                "node_label": sub_dataset,
                "is_feature_based": True,
                "graph_type": graph_type,
                "parameter": parameters[sub_dataset][graph_type],
                "laplacian_type": laplacian_type,
                "number_of_eigenvectors": number_of_eigenvectors,
                "use_kmean_for_silhouette": use_kmean_for_silhouette
            })

# Print or analyze the configurations to ensure correctness
# for experiment in experiments:
#     print(experiment)

# %%
def run_experiments(driver):
    results = []
    total_experiments = len(experiments)

    for idx, config in enumerate(experiments, 1):
        query = """
        WITH simkit.experimental_spectralClustering({
            node_label: $node_label,
            is_feature_based: $is_feature_based,
            distance_measure: "euclidean",
            graph_type: $graph_type,
            parameter: $parameter,
            remove_columns: "Index,target",
            laplacian_type: $laplacian_type,
            number_of_eigenvectors: $number_of_eigenvectors,
            number_of_iterations: "100",
            distance_measure_kmean: "euclidean",
            target_column: "target",
            use_kmean_for_silhouette: $use_kmean_for_silhouette,
            seed: 42
        }) AS result
        RETURN result.silhouette_score AS silhouette_score, 
               result.rand_index AS rand_index,
               result.total_time AS total_time,
               result.affinity_time AS affinity_time,
               result.laplacian_time AS laplacian_time,
               result.clustering_time AS clustering_time,
               result.adjusted_rand_index_time AS adjusted_rand_index_time
        """

        # Measure Memory and CPU Usage Before Query Execution
        memory_before = psutil.virtual_memory().used
        cpu_before = psutil.cpu_percent(interval=None)

        # Execute the Query and Measure Time
        start_time = time.perf_counter()
        data, _, _, _ = run_query(driver, query, config)
        elapsed_time = time.perf_counter() - start_time

        # Measure Memory and CPU Usage After Query Execution
        memory_after = psutil.virtual_memory().used
        cpu_after = psutil.cpu_percent(interval=None)

        # Calculate Metrics
        memory_used = (memory_after - memory_before) / 1e6  # Memory in MB
        cpu_used = (cpu_before + cpu_after) / 2  # Average CPU usage

        # Extract Results from Java
        silhouette_score = data['silhouette_score'] if data else None
        rand_index = data['rand_index'] if data else None
        total_time = data['total_time'] if data else None
        affinity_time = data['affinity_time'] if data else None
        laplacian_time = data['laplacian_time'] if data else None
        clustering_time = data['clustering_time'] if data else None
        adjusted_rand_index_time = data['adjusted_rand_index_time'] if data else None

        # Save Results
        results.append({
            **config,
            "silhouette_score": silhouette_score,
            "rand_index": rand_index,
            "total_time": total_time or elapsed_time,
            "affinity_time": affinity_time,
            "laplacian_time": laplacian_time,
            "clustering_time": clustering_time,
            "adjusted_rand_index_time": adjusted_rand_index_time,
            "memory_used": memory_used,
            "cpu_used": cpu_used
        })

        print(f"Completed experiment {idx}/{total_experiments} with config: {config}")

    driver.close()
    return results

# %%
# # Example scheduling and execution
# def job():
#     print("Running experiments...")
#     result_data = run_experiments(driver)
#     # Save to DataFrame and then to CSV
#     df = pd.DataFrame(result_data)
#     df.to_csv("iris_results.csv", index=False)
#     print("Experiments completed and saved.")

# schedule.every().day.at("01:00").do(job)

# # Loop to keep the scheduler running
# while True:
#     schedule.run_pending()
#     time.sleep(60)  # wait one minute

print("Running experiments...")
result_data3 = run_experiments(driver)
# Save to DataFrame and then to CSV
df3 = pd.DataFrame(result_data3)
df3.to_csv("madelon_results3.csv", index=False)
print("Experiments completed and saved.")
# Out:
# Running experiments...
# Failed to read from defunct connection IPv4Address(('localhost', 7687)) (ResolvedIPv4Address(('127.0.0.1', 7687)))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 18
#       1 # # Example scheduling and execution
#       2 # def job():
#       3 #     print("Running experiments...")
#    (...)
#      14 #     schedule.run_pending()
#      15 #     time.sleep(60)  # wait one minute
#      17 print("Running experiments...")
# ---> 18 result_data3 = run_experiments(driver)
#      19 # Save to DataFrame and then to CSV
#      20 df3 = pd.DataFrame(result_data3)
#
# Cell In[6], line 37, in run_experiments(driver)
#      35 # Execute the Query and Measure Time
#      36 start_time = time.perf_counter()
# ---> 37 data, _, _, _ = run_query(driver, query, config)
#      38 elapsed_time = time.perf_counter() - start_time
#      40 # Measure Memory and CPU Usage After Query Execution
#
# Cell In[4], line 12, in run_query(driver, query, parameters)
#      10 with driver.session() as session:
#      11     result = session.run(query, parameters)
# ---> 12     record = result.single()
#      13     data = record.data() if record else None
#      15 # End time and resources
#
# File ~/.pyenv/versions/3.8.14/lib/python3.8/site-packages/neo4j/_sync/work/result.py:589, in Result.single(self, strict)
#     553 @NonConcurrentMethodChecker.non_concurrent_method
#     554 def single(self, strict: bool = False) -> t.Optional[Record]:
#     555     """Obtain the next and only remaining record or None.
#     556
#     557     Calling this method always exhausts the result.
#    (...)
#     587         * Can raise :exc:`.ResultConsumedError`.
#     588     """
# --> 589     self._buffer(2)
#     590     buffer = self._record_buffer
#     591     self._record_buffer = deque()
#
# File ~/.pyenv/versions/3.8.14/lib/python3.8/site-packages/neo4j/_sync/work/result.py:426, in Result._buffer(self, n)
#     424     return
#     425 record_buffer = deque()
# --> 426 for record in self:
#     427     record_buffer.append(record)
#     428     if n is not None and len(record_buffer) >= n:
#
# File ~/.pyenv/versions/3.8.14/lib/python3.8/site-packages/neo4j/_sync/work/result.py:378, in Result.__iter__(self)
#     376     yield self._record_buffer.popleft()
#     377 elif self._streaming:
# --> 378     self._connection.fetch_message()
#     379 elif self._discarding:
#     380     self._discard()
#
# File ~/.pyenv/versions/3.8.14/lib/python3.8/site-packages/neo4j/_sync/io/_common.py:178, in ConnectionErrorHandler.__getattr__.<locals>.outer.<locals>.inner(*args, **kwargs)
#     176 def inner(*args, **kwargs):
#     177     try:
# --> 178         func(*args, **kwargs)
#     179     except (Neo4jError, ServiceUnavailable, SessionExpired) as exc:
#     180         assert not asyncio.iscoroutinefunction(self.__on_error)
#
# File ~/.pyenv/versions/3.8.14/lib/python3.8/site-packages/neo4j/_sync/io/_bolt.py:857, in Bolt.fetch_message(self)
#     854     return 0, 0
#     856 # Receive exactly one message
# --> 857 tag, fields = self.inbox.pop(
#     858     hydration_hooks=self.responses[0].hydration_hooks
#     859 )
#     860 res = self._process_message(tag, fields)
#     861 self.idle_since = monotonic()
#
# File ~/.pyenv/versions/3.8.14/lib/python3.8/site-packages/neo4j/_sync/io/_common.py:72, in Inbox.pop(self, hydration_hooks)
#      71 def pop(self, hydration_hooks):
# ---> 72     self._buffer_one_chunk()
#      73     try:
#      74         size, tag = self._unpacker.unpack_structure_header()
#
# File ~/.pyenv/versions/3.8.14/lib/python3.8/site-packages/neo4j/_sync/io/_common.py:51, in Inbox._buffer_one_chunk(self)
#      48 while True:
#      49     while chunk_size == 0:
#      50         # Determine the chunk size and skip noop
# ---> 51         receive_into_buffer(self._socket, self._buffer, 2)
#      52         chunk_size = self._buffer.pop_u16()
#      53         if chunk_size == 0:
#
# File ~/.pyenv/versions/3.8.14/lib/python3.8/site-packages/neo4j/_sync/io/_common.py:326, in receive_into_buffer(sock, buffer, n_bytes)
#     324 with memoryview(buffer.data) as view:
#     325     while buffer.used < end:
# --> 326         n = sock.recv_into(view[buffer.used:end], end - buffer.used)
#     327         if n == 0:
#     328             raise OSError("No data")
#
# File ~/.pyenv/versions/3.8.14/lib/python3.8/site-packages/neo4j/_async_compat/network/_bolt_socket.py:493, in BoltSocket.recv_into(self, buffer, nbytes)
#     492 def recv_into(self, buffer, nbytes):
# --> 493     return self._wait_for_io(self._socket.recv_into, buffer, nbytes)
#
# File ~/.pyenv/versions/3.8.14/lib/python3.8/site-packages/neo4j/_async_compat/network/_bolt_socket.py:468, in BoltSocket._wait_for_io(self, func, *args, **kwargs)
#     466 def _wait_for_io(self, func, *args, **kwargs):
#     467     if self._deadline is None:
# --> 468         return func(*args, **kwargs)
#     469     timeout = self._socket.gettimeout()
#     470     deadline_timeout = self._deadline.to_timeout()
#
# KeyboardInterrupt:

# %%
result_data1
