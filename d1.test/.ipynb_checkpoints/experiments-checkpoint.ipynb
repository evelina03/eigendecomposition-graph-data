# %%
import sys
import os
import time
import psutil
import pandas as pd
from neo4j import GraphDatabase

# %%
# Database connection setup
uri = "bolt://localhost:7687"
user = "neo4j"
password = "eigen1234"
database_name="d1.iris"
driver = GraphDatabase.driver(uri, auth=(user, password))

# %%
def check_connection():
    try:
        # Establish a session with the specified database
        # with driver.session(database=database_name) as session:
        with driver.session() as session:
            # Run a simple query to check the connection
            result = session.run("RETURN 'Connection to database successful' AS message")
            for record in result:
                print(record["message"])
    except Exception as e:
        print("Error connecting to the database:", e)

# Call the check_connection function
check_connection()
# Out:
# Connection to database successful

# %%
# Function to run a query and measure performance metrics
def run_query(driver, query, parameters):
    # Start time and resources
    process = psutil.Process(os.getpid())
    start_time = time.time()
    start_cpu_times = process.cpu_times()
    start_mem = process.memory_info().rss  # Resident Set Size

    # with driver.session(database=database_name) as session:
    with driver.session() as session:
        result = session.run(query, parameters)
        record = result.single()
        data = record.data() if record else None

    # End time and resources
    end_time = time.time()
    end_cpu_times = process.cpu_times()
    end_mem = process.memory_info().rss

    # Calculations
    duration = end_time - start_time
    cpu_used = (end_cpu_times.user + end_cpu_times.system) - (start_cpu_times.user + start_cpu_times.system)
    memory_used = (end_mem - start_mem) / (1024 ** 2)  # Convert to MB

    return data, duration, memory_used, cpu_used

# %%
# Predefined experiments configurations with all combinations for each sub-dataset
experiments = []

# Define graph types and Laplacian methods
graph_types = ["full", "eps", "knn", "mknn"]
laplacian_types = ["sym", "rw", "ad"]

# Define parameters for each graph type per sub-dataset
parameters = {
    "iris_33": {"full": "5", "eps": "1.138", "knn": "8", "mknn": "6"},
    "iris_66": {"full": "5", "eps": "0.904", "knn": "16", "mknn": "15"},
    "iris_full": {"full": "11", "eps": "1.111", "knn": "10", "mknn": "30"}
}

# Define number of eigenvectors and silhouette usage (common for all experiments)
number_of_eigenvectors = 3
use_kmean_for_silhouette = False

# Generate experiment configurations for each sub-dataset
sub_datasets = ["iris_33", "iris_66", "iris_full"]
for sub_dataset in sub_datasets:
    for graph_type in graph_types:
        for laplacian_type in laplacian_types:
            experiments.append({
                "node_label": sub_dataset,
                "is_feature_based": True,
                "graph_type": graph_type,
                "parameter": parameters[sub_dataset][graph_type],
                "laplacian_type": laplacian_type,
                "number_of_eigenvectors": number_of_eigenvectors,
                "use_kmean_for_silhouette": use_kmean_for_silhouette
            })

# Print or analyze the configurations to ensure correctness
# for experiment in experiments:
#     print(experiment)

# %%
# # Main function to run experiments
# def run_experiments(driver):
#     results = []
#     total_experiments = len(experiments)
#     for idx, config in enumerate(experiments, 1):
#         query = """
#         WITH simkit.spectralClustering({
#             node_label: $node_label,
#             is_feature_based: $is_feature_based,
#             distance_measure: "euclidean",
#             graph_type: $graph_type,
#             parameter: $parameter,
#             remove_columns: "Index,target",
#             laplacian_type: $laplacian_type,
#             number_of_eigenvectors: $number_of_eigenvectors,
#             number_of_iterations: "100",
#             distance_measure_kmean: "euclidean",
#             target_column: "target",
#             use_kmean_for_silhouette: $use_kmean_for_silhouette,
#             seed: 42
#         }) AS silhouette_score
#         WITH silhouette_score, simkit.adjustedRandIndex({
#             nodeSet: $node_label,
#             trueLabels: "target"
#         }) AS rand_index
#         RETURN silhouette_score, rand_index
#         """
#         # Run the combined query and collect metrics
#         data, duration, memory_used, cpu_used = run_query(driver, query, config)
#         silhouette_score = data['silhouette_score'] if data else None
#         rand_index = data['rand_index'] if data else None

#         # Save results
#         results.append({
#             **config,
#             "silhouette_score": silhouette_score,
#             "rand_index": rand_index,
#             "duration": duration,
#             "memory_used": memory_used,
#             "cpu_used": cpu_used
#         })
#         # Print progress after each experiment
#         print(f"Completed experiment {idx}/{total_experiments} with config: {config}")

#     driver.close()
#     return results

# %%
def run_experiments(driver):
    results = []
    total_experiments = len(experiments)

    for idx, config in enumerate(experiments, 1):
        query = """
        WITH simkit.experimental_spectralClustering({
            node_label: $node_label,
            is_feature_based: $is_feature_based,
            distance_measure: "euclidean",
            graph_type: $graph_type,
            parameter: $parameter,
            remove_columns: "Index,target",
            laplacian_type: $laplacian_type,
            number_of_eigenvectors: $number_of_eigenvectors,
            number_of_iterations: "100",
            distance_measure_kmean: "euclidean",
            target_column: "target",
            use_kmean_for_silhouette: $use_kmean_for_silhouette,
            seed: 42
        }) AS result
        RETURN result.silhouette_score AS silhouette_score, 
               result.rand_index AS rand_index,
               result.total_time AS total_time,
               result.affinity_time AS affinity_time,
               result.laplacian_time AS laplacian_time,
               result.clustering_time AS clustering_time,
               result.adjusted_rand_index_time AS adjusted_rand_index_time
        """

        # Measure Memory and CPU Usage Before Query Execution
        memory_before = psutil.virtual_memory().used
        cpu_before = psutil.cpu_percent(interval=None)

        # Execute the Query and Measure Time
        start_time = time.perf_counter()
        data, _, _, _ = run_query(driver, query, config)
        elapsed_time = time.perf_counter() - start_time

        # Measure Memory and CPU Usage After Query Execution
        memory_after = psutil.virtual_memory().used
        cpu_after = psutil.cpu_percent(interval=None)

        # Calculate Metrics
        memory_used = (memory_after - memory_before) / 1e6  # Memory in MB
        cpu_used = (cpu_before + cpu_after) / 2  # Average CPU usage

        # Extract Results from Java
        silhouette_score = data['silhouette_score'] if data else None
        rand_index = data['rand_index'] if data else None
        total_time = data['total_time'] if data else None
        affinity_time = data['affinity_time'] if data else None
        laplacian_time = data['laplacian_time'] if data else None
        clustering_time = data['clustering_time'] if data else None
        adjusted_rand_index_time = data['adjusted_rand_index_time'] if data else None

        # Save Results
        results.append({
            **config,
            "silhouette_score": silhouette_score,
            "rand_index": rand_index,
            "total_time": total_time or elapsed_time,
            "affinity_time": affinity_time,
            "laplacian_time": laplacian_time,
            "clustering_time": clustering_time,
            "adjusted_rand_index_time": adjusted_rand_index_time,
            "memory_used": memory_used,
            "cpu_used": cpu_used
        })

        print(f"Completed experiment {idx}/{total_experiments} with config: {config}")

    driver.close()
    return results

# %%
# # Example scheduling and execution
# def job():
#     print("Running experiments...")
#     result_data = run_experiments(driver)
#     # Save to DataFrame and then to CSV
#     df = pd.DataFrame(result_data)
#     df.to_csv("iris_results.csv", index=False)
#     print("Experiments completed and saved.")

# schedule.every().day.at("01:00").do(job)

# # Loop to keep the scheduler running
# while True:
#     schedule.run_pending()
#     time.sleep(60)  # wait one minute

print("Running experiments...")
result_data = run_experiments(driver)
# Save to DataFrame and then to CSV
df = pd.DataFrame(result_data)
df.to_csv("iris_results.csv", index=False)
print("Experiments completed and saved.")
# Out:
# Running experiments...
# Completed experiment 1/36 with config: {'node_label': 'iris_33', 'is_feature_based': True, 'graph_type': 'full', 'parameter': '5', 'laplacian_type': 'sym', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 2/36 with config: {'node_label': 'iris_33', 'is_feature_based': True, 'graph_type': 'full', 'parameter': '5', 'laplacian_type': 'rw', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 3/36 with config: {'node_label': 'iris_33', 'is_feature_based': True, 'graph_type': 'full', 'parameter': '5', 'laplacian_type': 'ad', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 4/36 with config: {'node_label': 'iris_33', 'is_feature_based': True, 'graph_type': 'eps', 'parameter': '1.138', 'laplacian_type': 'sym', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 5/36 with config: {'node_label': 'iris_33', 'is_feature_based': True, 'graph_type': 'eps', 'parameter': '1.138', 'laplacian_type': 'rw', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 6/36 with config: {'node_label': 'iris_33', 'is_feature_based': True, 'graph_type': 'eps', 'parameter': '1.138', 'laplacian_type': 'ad', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 7/36 with config: {'node_label': 'iris_33', 'is_feature_based': True, 'graph_type': 'knn', 'parameter': '8', 'laplacian_type': 'sym', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 8/36 with config: {'node_label': 'iris_33', 'is_feature_based': True, 'graph_type': 'knn', 'parameter': '8', 'laplacian_type': 'rw', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 9/36 with config: {'node_label': 'iris_33', 'is_feature_based': True, 'graph_type': 'knn', 'parameter': '8', 'laplacian_type': 'ad', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 10/36 with config: {'node_label': 'iris_33', 'is_feature_based': True, 'graph_type': 'mknn', 'parameter': '6', 'laplacian_type': 'sym', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 11/36 with config: {'node_label': 'iris_33', 'is_feature_based': True, 'graph_type': 'mknn', 'parameter': '6', 'laplacian_type': 'rw', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 12/36 with config: {'node_label': 'iris_33', 'is_feature_based': True, 'graph_type': 'mknn', 'parameter': '6', 'laplacian_type': 'ad', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 13/36 with config: {'node_label': 'iris_66', 'is_feature_based': True, 'graph_type': 'full', 'parameter': '5', 'laplacian_type': 'sym', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 14/36 with config: {'node_label': 'iris_66', 'is_feature_based': True, 'graph_type': 'full', 'parameter': '5', 'laplacian_type': 'rw', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 15/36 with config: {'node_label': 'iris_66', 'is_feature_based': True, 'graph_type': 'full', 'parameter': '5', 'laplacian_type': 'ad', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 16/36 with config: {'node_label': 'iris_66', 'is_feature_based': True, 'graph_type': 'eps', 'parameter': '0.904', 'laplacian_type': 'sym', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 17/36 with config: {'node_label': 'iris_66', 'is_feature_based': True, 'graph_type': 'eps', 'parameter': '0.904', 'laplacian_type': 'rw', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 18/36 with config: {'node_label': 'iris_66', 'is_feature_based': True, 'graph_type': 'eps', 'parameter': '0.904', 'laplacian_type': 'ad', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 19/36 with config: {'node_label': 'iris_66', 'is_feature_based': True, 'graph_type': 'knn', 'parameter': '16', 'laplacian_type': 'sym', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 20/36 with config: {'node_label': 'iris_66', 'is_feature_based': True, 'graph_type': 'knn', 'parameter': '16', 'laplacian_type': 'rw', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 21/36 with config: {'node_label': 'iris_66', 'is_feature_based': True, 'graph_type': 'knn', 'parameter': '16', 'laplacian_type': 'ad', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 22/36 with config: {'node_label': 'iris_66', 'is_feature_based': True, 'graph_type': 'mknn', 'parameter': '15', 'laplacian_type': 'sym', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 23/36 with config: {'node_label': 'iris_66', 'is_feature_based': True, 'graph_type': 'mknn', 'parameter': '15', 'laplacian_type': 'rw', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 24/36 with config: {'node_label': 'iris_66', 'is_feature_based': True, 'graph_type': 'mknn', 'parameter': '15', 'laplacian_type': 'ad', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 25/36 with config: {'node_label': 'iris_full', 'is_feature_based': True, 'graph_type': 'full', 'parameter': '11', 'laplacian_type': 'sym', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 26/36 with config: {'node_label': 'iris_full', 'is_feature_based': True, 'graph_type': 'full', 'parameter': '11', 'laplacian_type': 'rw', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 27/36 with config: {'node_label': 'iris_full', 'is_feature_based': True, 'graph_type': 'full', 'parameter': '11', 'laplacian_type': 'ad', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 28/36 with config: {'node_label': 'iris_full', 'is_feature_based': True, 'graph_type': 'eps', 'parameter': '1.111', 'laplacian_type': 'sym', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 29/36 with config: {'node_label': 'iris_full', 'is_feature_based': True, 'graph_type': 'eps', 'parameter': '1.111', 'laplacian_type': 'rw', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 30/36 with config: {'node_label': 'iris_full', 'is_feature_based': True, 'graph_type': 'eps', 'parameter': '1.111', 'laplacian_type': 'ad', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 31/36 with config: {'node_label': 'iris_full', 'is_feature_based': True, 'graph_type': 'knn', 'parameter': '10', 'laplacian_type': 'sym', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 32/36 with config: {'node_label': 'iris_full', 'is_feature_based': True, 'graph_type': 'knn', 'parameter': '10', 'laplacian_type': 'rw', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 33/36 with config: {'node_label': 'iris_full', 'is_feature_based': True, 'graph_type': 'knn', 'parameter': '10', 'laplacian_type': 'ad', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 34/36 with config: {'node_label': 'iris_full', 'is_feature_based': True, 'graph_type': 'mknn', 'parameter': '30', 'laplacian_type': 'sym', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 35/36 with config: {'node_label': 'iris_full', 'is_feature_based': True, 'graph_type': 'mknn', 'parameter': '30', 'laplacian_type': 'rw', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Completed experiment 36/36 with config: {'node_label': 'iris_full', 'is_feature_based': True, 'graph_type': 'mknn', 'parameter': '30', 'laplacian_type': 'ad', 'number_of_eigenvectors': 3, 'use_kmean_for_silhouette': False}
# Experiments completed and saved.

# %%
result_data
# Out:
# [{'node_label': 'iris_33',
#   'is_feature_based': True,
#   'graph_type': 'full',
#   'parameter': '5',
#   'laplacian_type': 'sym',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.518458550940038,
#   'rand_index': 0.5806451612903226,
#   'total_time': 4233.46525,
#   'affinity_time': 1220.411583,
#   'laplacian_time': 450.576209,
#   'clustering_time': 2271.322792,
#   'adjusted_rand_index_time': 229.165083,
#   'memory_used': -91.815936,
#   'cpu_used': 24.9},
#  {'node_label': 'iris_33',
#   'is_feature_based': True,
#   'graph_type': 'full',
#   'parameter': '5',
#   'laplacian_type': 'rw',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.5142268444868442,
#   'rand_index': 0.8236968050704954,
#   'total_time': 2685.972417,
#   'affinity_time': 292.824209,
#   'laplacian_time': 251.424917,
#   'clustering_time': 1878.113375,
#   'adjusted_rand_index_time': 238.804209,
#   'memory_used': -33.34144,
#   'cpu_used': 10.95},
#  {'node_label': 'iris_33',
#   'is_feature_based': True,
#   'graph_type': 'full',
#   'parameter': '5',
#   'laplacian_type': 'ad',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.509421546992658,
#   'rand_index': 0.6656318716854224,
#   'total_time': 2456.478333,
#   'affinity_time': 163.167333,
#   'laplacian_time': 281.905667,
#   'clustering_time': 1749.129125,
#   'adjusted_rand_index_time': 240.924208,
#   'memory_used': -146.194432,
#   'cpu_used': 14.7},
#  {'node_label': 'iris_33',
#   'is_feature_based': True,
#   'graph_type': 'eps',
#   'parameter': '1.138',
#   'laplacian_type': 'sym',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.2707105116698875,
#   'rand_index': 0.1529423479040128,
#   'total_time': 2295.646125,
#   'affinity_time': 201.569083,
#   'laplacian_time': 239.2395,
#   'clustering_time': 1610.374833,
#   'adjusted_rand_index_time': 224.305625,
#   'memory_used': 198.344704,
#   'cpu_used': 13.85},
#  {'node_label': 'iris_33',
#   'is_feature_based': True,
#   'graph_type': 'eps',
#   'parameter': '1.138',
#   'laplacian_type': 'rw',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.12296114471630894,
#   'rand_index': 0.2767667303326246,
#   'total_time': 2076.082542,
#   'affinity_time': 173.86475,
#   'laplacian_time': 219.427917,
#   'clustering_time': 1421.469125,
#   'adjusted_rand_index_time': 234.046542,
#   'memory_used': -37.715968,
#   'cpu_used': 13.2},
#  {'node_label': 'iris_33',
#   'is_feature_based': True,
#   'graph_type': 'eps',
#   'parameter': '1.138',
#   'laplacian_type': 'ad',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.2707105116698875,
#   'rand_index': 0.1529423479040128,
#   'total_time': 2511.80175,
#   'affinity_time': 191.573167,
#   'laplacian_time': 238.635083,
#   'clustering_time': 1837.295042,
#   'adjusted_rand_index_time': 222.701833,
#   'memory_used': -37.535744,
#   'cpu_used': 71.4},
#  {'node_label': 'iris_33',
#   'is_feature_based': True,
#   'graph_type': 'knn',
#   'parameter': '8',
#   'laplacian_type': 'sym',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.4813444036156274,
#   'rand_index': 0.6900050735667174,
#   'total_time': 2072.248208,
#   'affinity_time': 137.40275,
#   'laplacian_time': 155.033167,
#   'clustering_time': 1523.05125,
#   'adjusted_rand_index_time': 230.317333,
#   'memory_used': 5.931008,
#   'cpu_used': 23.15},
#  {'node_label': 'iris_33',
#   'is_feature_based': True,
#   'graph_type': 'knn',
#   'parameter': '8',
#   'laplacian_type': 'rw',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.32280490728849487,
#   'rand_index': 0.5508873047171242,
#   'total_time': 2142.556333,
#   'affinity_time': 100.845,
#   'laplacian_time': 132.762167,
#   'clustering_time': 1649.17575,
#   'adjusted_rand_index_time': 238.286625,
#   'memory_used': -7.323648,
#   'cpu_used': 22.0},
#  {'node_label': 'iris_33',
#   'is_feature_based': True,
#   'graph_type': 'knn',
#   'parameter': '8',
#   'laplacian_type': 'ad',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.4813444036156274,
#   'rand_index': 0.6900050735667174,
#   'total_time': 1970.450542,
#   'affinity_time': 108.268334,
#   'laplacian_time': 145.066792,
#   'clustering_time': 1458.351042,
#   'adjusted_rand_index_time': 232.7915,
#   'memory_used': -79.200256,
#   'cpu_used': 21.7},
#  {'node_label': 'iris_33',
#   'is_feature_based': True,
#   'graph_type': 'mknn',
#   'parameter': '6',
#   'laplacian_type': 'sym',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.632815648926268,
#   'rand_index': 0.5607476635514019,
#   'total_time': 1951.089792,
#   'affinity_time': 106.912375,
#   'laplacian_time': 139.432083,
#   'clustering_time': 1441.963375,
#   'adjusted_rand_index_time': 239.294042,
#   'memory_used': 83.902464,
#   'cpu_used': 18.4},
#  {'node_label': 'iris_33',
#   'is_feature_based': True,
#   'graph_type': 'mknn',
#   'parameter': '6',
#   'laplacian_type': 'rw',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.15917107120906868,
#   'rand_index': 0.41349560930519186,
#   'total_time': 2041.106208,
#   'affinity_time': 83.847958,
#   'laplacian_time': 113.077208,
#   'clustering_time': 1585.117417,
#   'adjusted_rand_index_time': 238.012834,
#   'memory_used': -12.107776,
#   'cpu_used': 14.0},
#  {'node_label': 'iris_33',
#   'is_feature_based': True,
#   'graph_type': 'mknn',
#   'parameter': '6',
#   'laplacian_type': 'ad',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.26486829645327953,
#   'rand_index': 0.6278303300089886,
#   'total_time': 1836.841667,
#   'affinity_time': 86.35675,
#   'laplacian_time': 112.154791,
#   'clustering_time': 1388.517959,
#   'adjusted_rand_index_time': 227.0305,
#   'memory_used': 9.060352,
#   'cpu_used': 15.0},
#  {'node_label': 'iris_66',
#   'is_feature_based': True,
#   'graph_type': 'full',
#   'parameter': '5',
#   'laplacian_type': 'sym',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.4941141297758348,
#   'rand_index': 0.9395472499306626,
#   'total_time': 4088.138583,
#   'affinity_time': 341.342041,
#   'laplacian_time': 586.659209,
#   'clustering_time': 2898.468166,
#   'adjusted_rand_index_time': 238.802375,
#   'memory_used': 65.077248,
#   'cpu_used': 12.0},
#  {'node_label': 'iris_66',
#   'is_feature_based': True,
#   'graph_type': 'full',
#   'parameter': '5',
#   'laplacian_type': 'rw',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.3727202064129596,
#   'rand_index': 0.8295059151009047,
#   'total_time': 3472.032792,
#   'affinity_time': 266.9805,
#   'laplacian_time': 531.7195,
#   'clustering_time': 2414.94825,
#   'adjusted_rand_index_time': 232.936625,
#   'memory_used': -67.305472,
#   'cpu_used': 11.25},
#  {'node_label': 'iris_66',
#   'is_feature_based': True,
#   'graph_type': 'full',
#   'parameter': '5',
#   'laplacian_type': 'ad',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.4456426254972349,
#   'rand_index': 0.8023496428809826,
#   'total_time': 4087.431542,
#   'affinity_time': 658.822167,
#   'laplacian_time': 800.744625,
#   'clustering_time': 2369.162625,
#   'adjusted_rand_index_time': 236.424541,
#   'memory_used': 28.082176,
#   'cpu_used': 12.6},
#  {'node_label': 'iris_66',
#   'is_feature_based': True,
#   'graph_type': 'eps',
#   'parameter': '0.904',
#   'laplacian_type': 'sym',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.2776305431692922,
#   'rand_index': 0.6525276056469272,
#   'total_time': 3518.283958,
#   'affinity_time': 527.36125,
#   'laplacian_time': 444.678334,
#   'clustering_time': 2290.830583,
#   'adjusted_rand_index_time': 239.018,
#   'memory_used': -44.613632,
#   'cpu_used': 13.25},
#  {'node_label': 'iris_66',
#   'is_feature_based': True,
#   'graph_type': 'eps',
#   'parameter': '0.904',
#   'laplacian_type': 'rw',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.17752876732964606,
#   'rand_index': 0.9087069929201342,
#   'total_time': 3648.521584,
#   'affinity_time': 481.93875,
#   'laplacian_time': 639.298708,
#   'clustering_time': 2265.926292,
#   'adjusted_rand_index_time': 238.832,
#   'memory_used': 27.918336,
#   'cpu_used': 16.1},
#  {'node_label': 'iris_66',
#   'is_feature_based': True,
#   'graph_type': 'eps',
#   'parameter': '0.904',
#   'laplacian_type': 'ad',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.26349889786291825,
#   'rand_index': 0.4602426944493671,
#   'total_time': 3332.186875,
#   'affinity_time': 478.611125,
#   'laplacian_time': 402.096125,
#   'clustering_time': 2193.780458,
#   'adjusted_rand_index_time': 234.402042,
#   'memory_used': 36.470784,
#   'cpu_used': 66.25},
#  {'node_label': 'iris_66',
#   'is_feature_based': True,
#   'graph_type': 'knn',
#   'parameter': '16',
#   'laplacian_type': 'sym',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.4831632661866875,
#   'rand_index': 0.9695393119805663,
#   'total_time': 3060.397833,
#   'affinity_time': 212.512459,
#   'laplacian_time': 253.283416,
#   'clustering_time': 2349.41175,
#   'adjusted_rand_index_time': 228.184667,
#   'memory_used': 43.99104,
#   'cpu_used': 13.8},
#  {'node_label': 'iris_66',
#   'is_feature_based': True,
#   'graph_type': 'knn',
#   'parameter': '16',
#   'laplacian_type': 'rw',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.18871972591552785,
#   'rand_index': 0.4904615844991397,
#   'total_time': 2990.384125,
#   'affinity_time': 190.042625,
#   'laplacian_time': 249.749334,
#   'clustering_time': 2298.276959,
#   'adjusted_rand_index_time': 236.425333,
#   'memory_used': -73.367552,
#   'cpu_used': 9.15},
#  {'node_label': 'iris_66',
#   'is_feature_based': True,
#   'graph_type': 'knn',
#   'parameter': '16',
#   'laplacian_type': 'ad',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.12346055761918102,
#   'rand_index': 0.5663716814159292,
#   'total_time': 2997.7945,
#   'affinity_time': 182.5085,
#   'laplacian_time': 260.476041,
#   'clustering_time': 2295.465583,
#   'adjusted_rand_index_time': 235.31775,
#   'memory_used': 0.098304,
#   'cpu_used': 8.8},
#  {'node_label': 'iris_66',
#   'is_feature_based': True,
#   'graph_type': 'mknn',
#   'parameter': '15',
#   'laplacian_type': 'sym',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.4956357884103086,
#   'rand_index': 0.8840635017554571,
#   'total_time': 2949.342583,
#   'affinity_time': 171.379708,
#   'laplacian_time': 201.085666,
#   'clustering_time': 2324.293042,
#   'adjusted_rand_index_time': 230.444292,
#   'memory_used': -1.916928,
#   'cpu_used': 8.4},
#  {'node_label': 'iris_66',
#   'is_feature_based': True,
#   'graph_type': 'mknn',
#   'parameter': '15',
#   'laplacian_type': 'rw',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.504518865049383,
#   'rand_index': 0.7847621932747653,
#   'total_time': 2938.120084,
#   'affinity_time': 162.574375,
#   'laplacian_time': 208.88275,
#   'clustering_time': 2307.909583,
#   'adjusted_rand_index_time': 236.387042,
#   'memory_used': 8.68352,
#   'cpu_used': 59.4},
#  {'node_label': 'iris_66',
#   'is_feature_based': True,
#   'graph_type': 'mknn',
#   'parameter': '15',
#   'laplacian_type': 'ad',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.4052579134669107,
#   'rand_index': 0.6379118671935577,
#   'total_time': 2943.820667,
#   'affinity_time': 147.264209,
#   'laplacian_time': 196.235666,
#   'clustering_time': 2361.566667,
#   'adjusted_rand_index_time': 222.382666,
#   'memory_used': -38.862848,
#   'cpu_used': 10.45},
#  {'node_label': 'iris_full',
#   'is_feature_based': True,
#   'graph_type': 'full',
#   'parameter': '11',
#   'laplacian_type': 'sym',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.4819784798178228,
#   'rand_index': 0.9410449800736683,
#   'total_time': 5719.153458,
#   'affinity_time': 354.769417,
#   'laplacian_time': 1672.846208,
#   'clustering_time': 3422.844,
#   'adjusted_rand_index_time': 244.68875,
#   'memory_used': 118.095872,
#   'cpu_used': 11.4},
#  {'node_label': 'iris_full',
#   'is_feature_based': True,
#   'graph_type': 'full',
#   'parameter': '11',
#   'laplacian_type': 'rw',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.4797334464081528,
#   'rand_index': 0.8647830351074957,
#   'total_time': 5335.188,
#   'affinity_time': 374.227625,
#   'laplacian_time': 1577.136,
#   'clustering_time': 3127.009917,
#   'adjusted_rand_index_time': 232.380291,
#   'memory_used': -70.713344,
#   'cpu_used': 15.55},
#  {'node_label': 'iris_full',
#   'is_feature_based': True,
#   'graph_type': 'full',
#   'parameter': '11',
#   'laplacian_type': 'ad',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.46741633379813663,
#   'rand_index': 0.9204024125176882,
#   'total_time': 5099.814334,
#   'affinity_time': 370.5865,
#   'laplacian_time': 1352.909875,
#   'clustering_time': 3116.258709,
#   'adjusted_rand_index_time': 236.624667,
#   'memory_used': -33.636352,
#   'cpu_used': 11.25},
#  {'node_label': 'iris_full',
#   'is_feature_based': True,
#   'graph_type': 'eps',
#   'parameter': '1.111',
#   'laplacian_type': 'sym',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.08979073440622296,
#   'rand_index': 0.23236809379996445,
#   'total_time': 4175.676834,
#   'affinity_time': 314.37725,
#   'laplacian_time': 1370.472959,
#   'clustering_time': 2234.655125,
#   'adjusted_rand_index_time': 233.391459,
#   'memory_used': -20.086784,
#   'cpu_used': 8.2},
#  {'node_label': 'iris_full',
#   'is_feature_based': True,
#   'graph_type': 'eps',
#   'parameter': '1.111',
#   'laplacian_type': 'rw',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.21218090091931202,
#   'rand_index': 0.6527912692219905,
#   'total_time': 6248.48275,
#   'affinity_time': 1881.27925,
#   'laplacian_time': 1499.244125,
#   'clustering_time': 2607.835917,
#   'adjusted_rand_index_time': 236.018417,
#   'memory_used': 67.846144,
#   'cpu_used': 14.55},
#  {'node_label': 'iris_full',
#   'is_feature_based': True,
#   'graph_type': 'eps',
#   'parameter': '1.111',
#   'laplacian_type': 'ad',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.0886029251500464,
#   'rand_index': 0.244822463662579,
#   'total_time': 5651.941125,
#   'affinity_time': 1731.566167,
#   'laplacian_time': 1440.3715,
#   'clustering_time': 2226.538583,
#   'adjusted_rand_index_time': 232.948167,
#   'memory_used': -66.060288,
#   'cpu_used': 14.15},
#  {'node_label': 'iris_full',
#   'is_feature_based': True,
#   'graph_type': 'knn',
#   'parameter': '10',
#   'laplacian_type': 'sym',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.47514077006743444,
#   'rand_index': 0.97993200471804,
#   'total_time': 3754.514125,
#   'affinity_time': 236.049875,
#   'laplacian_time': 362.870791,
#   'clustering_time': 2912.202458,
#   'adjusted_rand_index_time': 221.446416,
#   'memory_used': 28.688384,
#   'cpu_used': 20.5},
#  {'node_label': 'iris_full',
#   'is_feature_based': True,
#   'graph_type': 'knn',
#   'parameter': '10',
#   'laplacian_type': 'rw',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.492123523156286,
#   'rand_index': 0.40117429118653647,
#   'total_time': 3920.903208,
#   'affinity_time': 237.265375,
#   'laplacian_time': 362.142625,
#   'clustering_time': 3065.976875,
#   'adjusted_rand_index_time': 233.14825,
#   'memory_used': -17.350656,
#   'cpu_used': 20.3},
#  {'node_label': 'iris_full',
#   'is_feature_based': True,
#   'graph_type': 'knn',
#   'parameter': '10',
#   'laplacian_type': 'ad',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.47514077006743427,
#   'rand_index': 0.97993200471804,
#   'total_time': 4079.343583,
#   'affinity_time': 238.504792,
#   'laplacian_time': 370.859583,
#   'clustering_time': 3215.169875,
#   'adjusted_rand_index_time': 232.324458,
#   'memory_used': 32.93184,
#   'cpu_used': 15.6},
#  {'node_label': 'iris_full',
#   'is_feature_based': True,
#   'graph_type': 'mknn',
#   'parameter': '30',
#   'laplacian_type': 'sym',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.506643901136835,
#   'rand_index': 0.5806226037796237,
#   'total_time': 4193.574584,
#   'affinity_time': 401.222792,
#   'laplacian_time': 650.465,
#   'clustering_time': 2889.376625,
#   'adjusted_rand_index_time': 231.668042,
#   'memory_used': 13.713408,
#   'cpu_used': 9.7},
#  {'node_label': 'iris_full',
#   'is_feature_based': True,
#   'graph_type': 'mknn',
#   'parameter': '30',
#   'laplacian_type': 'rw',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.4988145232282682,
#   'rand_index': 0.7368687823578868,
#   'total_time': 4291.619625,
#   'affinity_time': 394.336625,
#   'laplacian_time': 462.850834,
#   'clustering_time': 3178.56725,
#   'adjusted_rand_index_time': 232.244875,
#   'memory_used': -113.360896,
#   'cpu_used': 8.6},
#  {'node_label': 'iris_full',
#   'is_feature_based': True,
#   'graph_type': 'mknn',
#   'parameter': '30',
#   'laplacian_type': 'ad',
#   'number_of_eigenvectors': 3,
#   'use_kmean_for_silhouette': False,
#   'silhouette_score': 0.48268772660722675,
#   'rand_index': 0.96006671645913,
#   'total_time': 4671.643875,
#   'affinity_time': 394.838917,
#   'laplacian_time': 649.169375,
#   'clustering_time': 3367.096,
#   'adjusted_rand_index_time': 236.288416,
#   'memory_used': 79.593472,
#   'cpu_used': 8.05}]
