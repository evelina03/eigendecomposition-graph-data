# %%
import sys
import os
import time
import psutil
import pandas as pd
from neo4j import GraphDatabase

# %%
# Database connection setup
uri = "neo4j://localhost:7688"
user = "neo4j"
password = "eigen1234"
database_name="d1.iris"
driver = GraphDatabase.driver(uri, auth=(user, password))

# %%
# Function to run a query and measure performance metrics
def run_query(driver, query, parameters):
    # Start time and resources
    process = psutil.Process(os.getpid())
    start_time = time.time()
    start_cpu_times = process.cpu_times()
    start_mem = process.memory_info().rss  # Resident Set Size

    # with driver.session(database=database_name) as session:
    with driver.session() as session:
        result = session.run(query, parameters)
        record = result.single()
        data = record.data() if record else None

    # End time and resources
    end_time = time.time()
    end_cpu_times = process.cpu_times()
    end_mem = process.memory_info().rss

    # Calculations
    duration = end_time - start_time
    cpu_used = (end_cpu_times.user + end_cpu_times.system) - (start_cpu_times.user + start_cpu_times.system)
    memory_used = (end_mem - start_mem) / (1024 ** 2)  # Convert to MB

    return data, duration, memory_used, cpu_used

# %%
# Predefined experiments configurations with all combinations for each sub-dataset
experiments = []

# Define graph types and Laplacian methods
graph_types = ["full", "eps", "knn", "mknn"]
laplacian_types = ["sym", "rw", "ad"]

# Define parameters for each graph type per sub-dataset
parameters = {
    "iris_33": {"full": "5", "eps": "1.14", "knn": "8", "mknn": "13"},
    "iris_66": {"full": "5", "eps": "1.112", "knn": "16", "mknn": "15"},
    "iris_full": {"full": "11", "eps": "1.155", "knn": "10", "mknn": "30"}
}

# Define number of eigenvectors and silhouette usage (common for all experiments)
number_of_eigenvectors = 3
use_kmean_for_silhouette = False

# Generate experiment configurations for each sub-dataset
sub_datasets = ["iris_33", "iris_66", "iris_full"]
for sub_dataset in sub_datasets:
    for graph_type in graph_types:
        for laplacian_type in laplacian_types:
            experiments.append({
                "node_label": sub_dataset,
                "is_feature_based": True,
                "graph_type": graph_type,
                "parameter": parameters[sub_dataset][graph_type],
                "laplacian_type": laplacian_type,
                "number_of_eigenvectors": number_of_eigenvectors,
                "use_kmean_for_silhouette": use_kmean_for_silhouette
            })

# Print or analyze the configurations to ensure correctness
# for experiment in experiments:
#     print(experiment)

# %%
# Main function to run experiments
def run_experiments(driver):
    results = []
    total_experiments = len(experiments)
    for idx, config in enumerate(experiments, 1):
        query = """
        WITH simkit.spectralClustering({
            node_label: $node_label,
            is_feature_based: $is_feature_based,
            distance_measure: "euclidean",
            graph_type: $graph_type,
            parameter: $parameter,
            remove_columns: "Index,target",
            laplacian_type: $laplacian_type,
            number_of_eigenvectors: $number_of_eigenvectors,
            number_of_iterations: "100",
            distance_measure_kmean: "euclidean",
            target_column: "target",
            use_kmean_for_silhouette: $use_kmean_for_silhouette,
            seed: 42
        }) AS silhouette_score
        WITH silhouette_score, simkit.adjustedRandIndex({
            nodeSet: $node_label,
            trueLabels: "target"
        }) AS rand_index
        RETURN silhouette_score, rand_index
        """
        # Run the combined query and collect metrics
        data, duration, memory_used, cpu_used = run_query(driver, query, config)
        silhouette_score = data['silhouette_score'] if data else None
        rand_index = data['rand_index'] if data else None

        # Save results
        results.append({
            **config,
            "silhouette_score": silhouette_score,
            "rand_index": rand_index,
            "duration": duration,
            "memory_used": memory_used,
            "cpu_used": cpu_used
        })
        # Print progress after each experiment
        print(f"Completed experiment {idx}/{total_experiments} with config: {config}")

    driver.close()
    return results

# %%
# # Example scheduling and execution
# def job():
#     print("Running experiments...")
#     result_data = run_experiments(driver)
#     # Save to DataFrame and then to CSV
#     df = pd.DataFrame(result_data)
#     df.to_csv("iris_results.csv", index=False)
#     print("Experiments completed and saved.")

# schedule.every().day.at("01:00").do(job)

# # Loop to keep the scheduler running
# while True:
#     schedule.run_pending()
#     time.sleep(60)  # wait one minute

print("Running experiments...")
result_data = run_experiments(driver)
# Save to DataFrame and then to CSV
df = pd.DataFrame(result_data)
df.to_csv("iris_results.csv", index=False)
print("Experiments completed and saved.")
# Out:
# Running experiments...
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[6], line 18
#       1 # # Example scheduling and execution
#       2 # def job():
#       3 #     print("Running experiments...")
#    (...)
#      14 #     schedule.run_pending()
#      15 #     time.sleep(60)  # wait one minute
#      17 print("Running experiments...")
# ---> 18 result_data = run_experiments(driver)
#      19 # Save to DataFrame and then to CSV
#      20 df = pd.DataFrame(result_data)
#
# Cell In[5], line 29, in run_experiments(driver)
#       6 query = """
#       7 WITH simkit.spectralClustering({
#       8     node_label: $node_label,
#    (...)
#      26 RETURN silhouette_score, rand_index
#      27 """
#      28 # Run the combined query and collect metrics
# ---> 29 data, duration, memory_used, cpu_used = run_query(driver, query, config)
#      30 silhouette_score = data['silhouette_score'] if data else None
#      31 rand_index = data['rand_index'] if data else None
#
# Cell In[3], line 12, in run_query(driver, query, parameters)
#      10 with driver.session() as session:
#      11     result = session.run(query, parameters)
# ---> 12     record = result.single()
#      13     data = record.data() if record else None
#      15 # End time and resources
#
# File ~/.local/lib/python3.10/site-packages/neo4j/_sync/work/result.py:605, in Result.single(self, strict)
#     568 @NonConcurrentMethodChecker._non_concurrent_method
#     569 def single(self, strict: bool = False) -> Record | None:
#     570     """
#     571     Obtain the next and only remaining record or None.
#     572
#    (...)
#     603         * Can raise :exc:`.ResultConsumedError`.
#     604     """
# --> 605     self._buffer(2)
#     606     buffer = self._record_buffer
#     607     self._record_buffer = deque()
#
# File ~/.local/lib/python3.10/site-packages/neo4j/_sync/work/result.py:443, in Result._buffer(self, n)
#     441     return
#     442 record_buffer = deque()
# --> 443 for record in self:
#     444     record_buffer.append(record)
#     445     if n is not None and len(record_buffer) >= n:
#
# File ~/.local/lib/python3.10/site-packages/neo4j/_sync/work/result.py:393, in Result.__iter__(self)
#     391     yield self._record_buffer.popleft()
#     392 elif self._streaming:
# --> 393     self._connection.fetch_message()
#     394 elif self._discarding:
#     395     self._discard()
#
# File ~/.local/lib/python3.10/site-packages/neo4j/_sync/io/_common.py:184, in ConnectionErrorHandler.__getattr__.<locals>.outer.<locals>.inner(*args, **kwargs)
#     182 def inner(*args, **kwargs):
#     183     try:
# --> 184         func(*args, **kwargs)
#     185     except (Neo4jError, ServiceUnavailable, SessionExpired) as exc:
#     186         assert not asyncio.iscoroutinefunction(self.__on_error)
#
# File ~/.local/lib/python3.10/site-packages/neo4j/_sync/io/_bolt.py:994, in Bolt.fetch_message(self)
#     990 # Receive exactly one message
#     991 tag, fields = self.inbox.pop(
#     992     hydration_hooks=self.responses[0].hydration_hooks
#     993 )
# --> 994 res = self._process_message(tag, fields)
#     995 self.idle_since = monotonic()
#     996 return res
#
# File ~/.local/lib/python3.10/site-packages/neo4j/_sync/io/_bolt4.py:494, in Bolt4x0._process_message(self, tag, fields)
#     492 self._server_state_manager.state = BoltStates.FAILED
#     493 try:
# --> 494     response.on_failure(summary_metadata or {})
#     495 except (ServiceUnavailable, DatabaseUnavailable):
#     496     if self.pool:
#
# File ~/.local/lib/python3.10/site-packages/neo4j/_sync/io/_common.py:254, in Response.on_failure(self, metadata)
#     252 handler = self.handlers.get("on_summary")
#     253 Util.callback(handler)
# --> 254 raise self._hydrate_error(metadata)
#
# ClientError: {code: Neo.ClientError.Procedure.ProcedureCallFailed} {message: Failed to invoke function `simkit.spectralClustering`: Caused by: java.net.ConnectException: Connection timed out (Connection timed out)}

# %%
result_data
